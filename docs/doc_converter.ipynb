# %% [markdown]
# ### 資料準備

# %%
# 引入套件
import pandas as pd

# %%
import openpyxl
# ram_df = pd.read_excel("./docs/0926_new.xlsx")

# %%
# 讀取 json 檔案包含轉換向量
df = pd.read_json("vector_all.json")

# %%
df
# Out:
#       class                                title  \
# 0      生活科技                         種瓜得瓜 AI也略懂略懂
# 1      生活科技                         眼見不為憑：假新聞攻防戰
# 2      生活科技                     演化，AI的第三條路！(1/2)
# 3      生活科技                         理解與預測：科學的兩條路
# 4      生活科技                      別中了社群媒體的圈套(2/2)
# ...     ...                                  ...
# 25223  環境能源                  利比亞重奪油港、出口恐增，油價再添壓力
# 25224  環境能源                 解決缺電雙管齊下，經濟部：核二廠備而不用
# 25225  環境能源     住宅太陽能夯！SunPower 推用戶貸款案 股價創 09 年高
# 25226  環境能源                  矽晶圓和電池報價破底，太陽能產業現陰霾
# 25227  環境能源  太陽能 ETF 飆近 5 年高！儲能爆發，今年綠能將供美 1/5 用電
#
#                                                      tag  \
# 0              虛假相關 因果關係 手寫數字 大數據與資料探勘 不變性 方法 MNIST 人工智慧
# 1      對抗生成網路 媒體識讀 倫理 人工智慧 稀疏編碼 Deepfake 假新聞 Sparse c...
# 2                       基因 機器學習 PID 演化 調諧規則 方法 人工智慧 遺傳編程
# 3                  人工智慧 康德 中文房間 錯覺 知識論 應用 本體論 悖論 科學研究的變革
# 4                           打卡 倫理 多巴胺 科技成癮與依賴 按讚 人工智慧 成癮
# ...                                                  ...
# 25223                                               None
# 25224                                               None
# 25225                                               None
# 25226                                               None
# 25227                                               None
#
#                              TF  \
# 0         資料 數字 Bottou AI 數據 顏色
# 1      影片 Deepfake 影像 資料 AI 假消息
# 2            遺傳 函數 規劃 電路 控制器 演化
# 3             一個 預測 理解 科學 人類 之間
# 4           多巴胺 媒體 社群 手機 釋放 使用者
# ...                         ...
# 25223        利比亞 OPEC 14 萬桶 減產
# 25224         核二廠 供電 號機 格架案 報告
# 25225    太陽能 貸款 SunPower 計畫 安裝
# 25226        太陽能 報價 中國 矽晶圓 amp
# 25227          太陽能 儲能 電力 美國 電池
#
#                                                      url  \
# 0      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 1      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 2      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 3      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 4      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# ...                                                  ...
# 25223  https://finance.technews.tw/2017/03/15/rising-...
# 25224  https://technews.tw/2017/04/13/kuosheng-nuclea...
# 25225  https://finance.technews.tw/2014/06/17/%e4%bd%...
# 25226  https://technews.tw/2016/07/04/silicon-wafer-b...
# 25227  https://technews.tw/2020/02/18/solar-plus-stor...
#
#                                                  content  \
# 0      方法 因果關係 大數據與資料探勘 種瓜得瓜 AI也略懂略懂 手寫數字 參考資料 L. Bot...
# 1      參考資料 「剛開始看覺得沒什麼問題，但仔細看之後會覺得不太對，但也說不出奇怪的地方在哪。」這...
# 2      電腦程式的演化，是個比數學函數複雜的例子。譬如利用迭代法及記憶方式為蛋白質序列進行分類的電腦...
# 3      「教」讓我們能交流所知的因果關係（如果按照這些規則，那麼你就可以完成除法）；「學」則讓我們串...
# 4      我們是否會像酒精跟藥物成癮那樣對手機「成癮」，這問題頗有爭議，不過無論是酒精、藥物還是手機，...
# ...                                                  ...
# 25223  石油輸出國組織（OPEC）減產出現疑慮，美國頁岩油又拚命增產，油市信心潰散，價格連日走低。就...
# 25224  核二廠 1 號機格架案動工，增加燃料棒裝載池空間，時代力量黨團要求應向立院報告。經濟部次長沈...
# 25225  全美第二大太陽能面板製造商SunPower Corp.在美國股市開盤前發布新聞稿宣佈，該公司...
# 25226  隨著中國太陽能搶裝潮結束，太陽能景氣又向下探底，矽晶圓和電池報價同步下殺，近日一般轉換效率的...
# 25227  綠能漸受歡迎，基金經理人、電力供應商、電廠、求電若渴的科技巨擘，都砸錢資助美國的「太陽能＋儲...
#
#                                           vector_content  \
# 0      [-0.021029852300000002, -0.0542514324, -0.0027...
# 1      [0.0209220685, -0.0199356694, -0.0100477496000...
# 2      [0.010877614800000001, 0.1293374151, -0.006410...
# 3      [0.0122648785, 0.0393077433, -0.0125984019, 0....
# 4      [0.0771951079, 0.027206542, -0.0130433952, -0....
# ...                                                  ...
# 25223  [-0.0677532032, 0.0909031257, -0.011235184, 0....
# 25224  [-0.0339421257, 0.0858471021, -0.012784712, 0....
# 25225  [-0.0447881632, 0.1195616573, -0.0072561293000...
# 25226  [-0.1070504785, -0.1365594715, -0.0100096073, ...
# 25227  [-0.0323677883, 0.0826153681, -0.0100744274, -...
#
#                                               train_word  \
# 0      種瓜得瓜 AI也略懂略懂生活科技資料 數字 Bottou AI 數據 顏色虛假相關 因果關係...
# 1      眼見不為憑：假新聞攻防戰生活科技影片 Deepfake 影像 資料 AI 假消息對抗生成網路...
# 2      演化，AI的第三條路！(1/2)生活科技遺傳 函數 規劃 電路 控制器 演化基因 機器學習 ...
# 3      理解與預測：科學的兩條路生活科技一個 預測 理解 科學 人類 之間人工智慧 康德 中文房間 ...
# 4      別中了社群媒體的圈套(2/2)生活科技多巴胺 媒體 社群 手機 釋放 使用者打卡 倫理 多巴...
# ...                                                  ...
# 25223  利比亞重奪油港、出口恐增，油價再添壓力環境能源利比亞 OPEC 14 萬桶 減產 石油輸出國...
# 25224  解決缺電雙管齊下，經濟部：核二廠備而不用環境能源核二廠 供電 號機 格架案 報告 核二廠 1...
# 25225  住宅太陽能夯！SunPower 推用戶貸款案 股價創 09 年高環境能源太陽能 貸款 Sun...
# 25226  矽晶圓和電池報價破底，太陽能產業現陰霾環境能源太陽能 報價 中國 矽晶圓 amp 隨著中國太...
# 25227  太陽能 ETF 飆近 5 年高！儲能爆發，今年綠能將供美 1/5 用電環境能源太陽能 儲能 ...
#
#                                                   vector  \
# 0      [-0.0583782196, 0.1031238064, -0.0113756964000...
# 1      [0.043455038200000004, 0.060704663400000004, -...
# 2      [0.0225472897, 0.0992054567, -0.0078522237, -0...
# 3      [0.0686305091, 0.0514615625, -0.0094612828, -0...
# 4      [0.1136551425, 0.0289493725, -0.012286108, -0....
# ...                                                  ...
# 25223  [-0.039790824100000004, 0.008907675700000001, ...
# 25224  [-0.0116125308, 0.08935615420000001, -0.014415...
# 25225  [-0.037492018200000005, 0.1061695144, -0.00896...
# 25226  [-0.09039378170000001, -0.1806803197, -0.01122...
# 25227  [-0.0194282606, -0.0997526571, -0.013165022200...
#
#                                             vector_title  \
# 0      [-0.0173872132, 0.11031571030000001, -0.016326...
# 1      [0.06334497780000001, 0.144509241, -0.01732851...
# 2      [0.0084472038, 0.153572455, -0.0110182399, -0....
# 3      [0.0314404219, 0.19583205880000001, -0.0118992...
# 4      [0.1116571501, 0.1034322381, -0.0180011783, 0....
# ...                                                  ...
# 25223  [-0.0216975473, -0.049634777000000005, -0.0142...
# 25224  [-0.0049787723, 0.1505208015, -0.0172369964, 0...
# 25225  [-0.0448014326, 0.0850963891, -0.0159920491, -...
# 25226  [-0.0100124273, -0.065633826, -0.0141598051, 0...
# 25227  [-0.0337350778, -0.11418613050000001, -0.01793...
#
#                                               vector_tag  \
# 0      [-0.0372301415, 0.2327384651, -0.0132301245, 0...
# 1      [0.0662990957, 0.129875198, -0.012187048800000...
# 2      [-0.0646500215, 0.22329041360000002, -0.008657...
# 3      [0.08189587300000001, 0.1672154069, -0.0134308...
# 4      [-0.005840742, 0.2770869434, -0.0137596214, -0...
# ...                                                  ...
# 25223             'NoneType' object is not subscriptable
# 25224             'NoneType' object is not subscriptable
# 25225             'NoneType' object is not subscriptable
# 25226             'NoneType' object is not subscriptable
# 25227             'NoneType' object is not subscriptable
#
#                                                vector_tf
# 0      [-0.148078233, 0.0561440252, -0.0104988152, 0....
# 1      [-0.0551759563, 0.0143376132, -0.0093437964, 0...
# 2      [-0.07414200160000001, 0.0640343577, -0.015786...
# 3      [0.0892356634, 0.2118693441, -0.01379486170000...
# 4      [0.0466845334, 0.0673067942, -0.0178314056, -0...
# ...                                                  ...
# 25223  [-0.10559444870000001, 0.051304854500000004, -...
# 25224  [0.0034979533, 0.1363986284, -0.0180752911, 0....
# 25225  [-0.0415744744, 0.08353496340000001, -0.013032...
# 25226  [-0.035629414000000005, -0.07000338290000001, ...
# 25227  [-0.014025541, 0.0538733564, -0.0211572647, -0...
#
# [25228 rows x 12 columns]

# %%
FLICKR_API_SECRET
# Out:
# '3accddb53bf7cf04'

# %%
import flickrapi
import pandas as pd
import requests

# 替换为您的 Flickr API 密钥和密钥
FLICKR_API_KEY = "073a28c2c7f17809b1f40862d8a495e5"
FLICKR_API_SECRET = "3accddb53bf7cf04"

# 初始化Flickr API
flickr = flickrapi.FlickrAPI(
    FLICKR_API_KEY, FLICKR_API_SECRET, format='parsed-json')

# 定義上傳圖片到Flickr的函式


def upload_to_flickr(image_path):
    response = flickr.upload(
        filename=image_path, is_public=0)  # is_public=0表示設為私人
    return response['photoid']


# 執行上傳並更新資料表
for index, row in df.iterrows():
    print(f"Uploading {index}...")
    image_path = f"images/{index}.png"
    photo_id = upload_to_flickr(image_path)
    photo_url = f"https://www.flickr.com/photos/{flickr.token.user_nsid}/{photo_id}/"
    df.at[index, 'flickr_url'] = photo_url

# 印出更新後的資料表
print(df)
# Out:
# Uploading 0...
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# Cell In[31], line 21
#      19 print(f"Uploading {index}...")
#      20 image_path = f"images/{index}.png"
# ---> 21 photo_id = upload_to_flickr(image_path)
#      22 photo_url = f"https://www.flickr.com/photos/{flickr.token.user_nsid}/{photo_id}/"
#      23 df.at[index, 'flickr_url'] = photo_url
#
# Cell In[31], line 14, in upload_to_flickr(image_path)
#      13 def upload_to_flickr(image_path):
# ---> 14     response = flickr.upload(filename=image_path, is_public=0)  # is_public=0表示設為私人
#      15     return response['photoid']
#
# File c:\Users\vm\Anaconda3\envs\liang_trello_finder\lib\site-packages\flickrapi\core.py:494, in FlickrAPI.upload(self, filename, fileobj, timeout, **kwargs)
#     431 def upload(self, filename, fileobj=None, timeout=None, **kwargs):
#     432     """Upload a file to flickr.
#     433
#     434     Be extra careful you spell the parameters correctly, or you will
#    (...)
#     491     Progress is a number between 0 and 100.
#     492     """
# --> 494     return self._upload_to_form(self.UPLOAD_URL, filename, fileobj, timeout=timeout, **kwargs)
#
# File c:\Users\vm\Anaconda3\envs\liang_trello_finder\lib\site-packages\flickrapi\core.py:533, in FlickrAPI._upload_to_form(self, form_url, filename, fileobj, timeout, **kwargs)
#     531     raise IllegalArgumentException("filename must be specified")
#     532 if not self.token_cache.token:
# --> 533     raise IllegalArgumentException("Authentication is required")
#     535 kwargs['api_key'] = self.flickr_oauth.key
#     537 # Figure out the response format
#
# IllegalArgumentException: Authentication is required

# %%
import pandas as pd
from imgurpython import ImgurClient


# 初始化ImgurClient，不需要提供access_token和refresh_token
client_id = '44fc1b4aeb65c74'
client_secret = '11e5567be772c29b514453caa9c23e38675c8500'
client = ImgurClient(client_id, client_secret)

# 上傳圖片並更新資料表


def upload_image_and_update_table(index):
    # 路徑設置
    image_path = f'images/{index}.png'

    # 上傳圖片到Imgur（使用匿名上傳）
    response = client.upload_from_path(image_path, anon=True)

    # 獲得上傳後的圖片連結
    uploaded_image_link = response['link']

    # 更新資料表
    df.loc[index, 'imgur_link'] = uploaded_image_link


# 根據index逐一處理
for index in df.index:
    if (index <= 96):
        continue
    print(f'正在處理第{index}筆資料...')
    upload_image_and_update_table(index)

# 打印更新後的資料表
print(df)
# Out:
# 正在處理第47筆資料...
# 正在處理第48筆資料...
# 正在處理第49筆資料...
# 正在處理第50筆資料...
# 正在處理第51筆資料...
# 正在處理第52筆資料...
# 正在處理第53筆資料...
# 正在處理第54筆資料...
# 正在處理第55筆資料...
# 正在處理第56筆資料...
# 正在處理第57筆資料...
# 正在處理第58筆資料...
# 正在處理第59筆資料...
# 正在處理第60筆資料...
# 正在處理第61筆資料...
# 正在處理第62筆資料...
# 正在處理第63筆資料...
# 正在處理第64筆資料...
# 正在處理第65筆資料...
# 正在處理第66筆資料...
# 正在處理第67筆資料...
# 正在處理第68筆資料...
# 正在處理第69筆資料...
# 正在處理第70筆資料...
# 正在處理第71筆資料...
# 正在處理第72筆資料...
# 正在處理第73筆資料...
# 正在處理第74筆資料...
# 正在處理第75筆資料...
# 正在處理第76筆資料...
# 正在處理第77筆資料...
# 正在處理第78筆資料...
# 正在處理第79筆資料...
# 正在處理第80筆資料...
# 正在處理第81筆資料...
# 正在處理第82筆資料...
# 正在處理第83筆資料...
# 正在處理第84筆資料...
# 正在處理第85筆資料...
# 正在處理第86筆資料...
# 正在處理第87筆資料...
# 正在處理第88筆資料...
# 正在處理第89筆資料...
# 正在處理第90筆資料...
# 正在處理第91筆資料...
# 正在處理第92筆資料...
# 正在處理第93筆資料...
# 正在處理第94筆資料...
# 正在處理第95筆資料...
# 正在處理第96筆資料...
# 正在處理第97筆資料...
# ---------------------------------------------------------------------------
# ImgurClientRateLimitError                 Traceback (most recent call last)
# Cell In[37], line 29
#      27         continue
#      28     print(f'正在處理第{index}筆資料...')
# ---> 29     upload_image_and_update_table(index)
#      31 # 打印更新後的資料表
#      32 print(df)
#
# Cell In[37], line 16, in upload_image_and_update_table(index)
#      13 image_path = f'images/{index}.png'
#      15 # 上傳圖片到Imgur（使用匿名上傳）
# ---> 16 response = client.upload_from_path(image_path, anon=True)
#      18 # 獲得上傳後的圖片連結
#      19 uploaded_image_link = response['link']
#
# File c:\Users\vm\Anaconda3\envs\liang_trello_finder\lib\site-packages\imgurpython\client.py:596, in ImgurClient.upload_from_path(self, path, config, anon)
#     593 data.update({meta: config[meta] for meta in set(self.allowed_image_fields).intersection(config.keys())})
#     594 fd.close()
# --> 596 return self.make_request('POST', 'upload', data, anon)
#
# File c:\Users\vm\Anaconda3\envs\liang_trello_finder\lib\site-packages\imgurpython\client.py:153, in ImgurClient.make_request(self, method, route, data, force_anon)
#     151 # Rate-limit check
#     152 if response.status_code == 429:
# --> 153     raise ImgurClientRateLimitError()
#     155 try:
#     156     response_data = response.json()
#
# ImgurClientRateLimitError: Rate-limit exceeded!

# %%
df
# Out:
#       class                                title  \
# 0      生活科技                         種瓜得瓜 AI也略懂略懂
# 1      生活科技                         眼見不為憑：假新聞攻防戰
# 2      生活科技                     演化，AI的第三條路！(1/2)
# 3      生活科技                         理解與預測：科學的兩條路
# 4      生活科技                      別中了社群媒體的圈套(2/2)
# ...     ...                                  ...
# 25223  環境能源                  利比亞重奪油港、出口恐增，油價再添壓力
# 25224  環境能源                 解決缺電雙管齊下，經濟部：核二廠備而不用
# 25225  環境能源     住宅太陽能夯！SunPower 推用戶貸款案 股價創 09 年高
# 25226  環境能源                  矽晶圓和電池報價破底，太陽能產業現陰霾
# 25227  環境能源  太陽能 ETF 飆近 5 年高！儲能爆發，今年綠能將供美 1/5 用電
#
#                                                      tag  \
# 0              虛假相關 因果關係 手寫數字 大數據與資料探勘 不變性 方法 MNIST 人工智慧
# 1      對抗生成網路 媒體識讀 倫理 人工智慧 稀疏編碼 Deepfake 假新聞 Sparse c...
# 2                       基因 機器學習 PID 演化 調諧規則 方法 人工智慧 遺傳編程
# 3                  人工智慧 康德 中文房間 錯覺 知識論 應用 本體論 悖論 科學研究的變革
# 4                           打卡 倫理 多巴胺 科技成癮與依賴 按讚 人工智慧 成癮
# ...                                                  ...
# 25223                                               None
# 25224                                               None
# 25225                                               None
# 25226                                               None
# 25227                                               None
#
#                              TF  \
# 0         資料 數字 Bottou AI 數據 顏色
# 1      影片 Deepfake 影像 資料 AI 假消息
# 2            遺傳 函數 規劃 電路 控制器 演化
# 3             一個 預測 理解 科學 人類 之間
# 4           多巴胺 媒體 社群 手機 釋放 使用者
# ...                         ...
# 25223        利比亞 OPEC 14 萬桶 減產
# 25224         核二廠 供電 號機 格架案 報告
# 25225    太陽能 貸款 SunPower 計畫 安裝
# 25226        太陽能 報價 中國 矽晶圓 amp
# 25227          太陽能 儲能 電力 美國 電池
#
#                                                      url  \
# 0      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 1      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 2      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 3      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# 4      https://highscope.ch.ntu.edu.tw/wordpress/?p=8...
# ...                                                  ...
# 25223  https://finance.technews.tw/2017/03/15/rising-...
# 25224  https://technews.tw/2017/04/13/kuosheng-nuclea...
# 25225  https://finance.technews.tw/2014/06/17/%e4%bd%...
# 25226  https://technews.tw/2016/07/04/silicon-wafer-b...
# 25227  https://technews.tw/2020/02/18/solar-plus-stor...
#
#                                                  content  \
# 0      方法 因果關係 大數據與資料探勘 種瓜得瓜 AI也略懂略懂 手寫數字 參考資料 L. Bot...
# 1      參考資料 「剛開始看覺得沒什麼問題，但仔細看之後會覺得不太對，但也說不出奇怪的地方在哪。」這...
# 2      電腦程式的演化，是個比數學函數複雜的例子。譬如利用迭代法及記憶方式為蛋白質序列進行分類的電腦...
# 3      「教」讓我們能交流所知的因果關係（如果按照這些規則，那麼你就可以完成除法）；「學」則讓我們串...
# 4      我們是否會像酒精跟藥物成癮那樣對手機「成癮」，這問題頗有爭議，不過無論是酒精、藥物還是手機，...
# ...                                                  ...
# 25223  石油輸出國組織（OPEC）減產出現疑慮，美國頁岩油又拚命增產，油市信心潰散，價格連日走低。就...
# 25224  核二廠 1 號機格架案動工，增加燃料棒裝載池空間，時代力量黨團要求應向立院報告。經濟部次長沈...
# 25225  全美第二大太陽能面板製造商SunPower Corp.在美國股市開盤前發布新聞稿宣佈，該公司...
# 25226  隨著中國太陽能搶裝潮結束，太陽能景氣又向下探底，矽晶圓和電池報價同步下殺，近日一般轉換效率的...
# 25227  綠能漸受歡迎，基金經理人、電力供應商、電廠、求電若渴的科技巨擘，都砸錢資助美國的「太陽能＋儲...
#
#                                           vector_content  \
# 0      [-0.021029852300000002, -0.0542514324, -0.0027...
# 1      [0.0209220685, -0.0199356694, -0.0100477496000...
# 2      [0.010877614800000001, 0.1293374151, -0.006410...
# 3      [0.0122648785, 0.0393077433, -0.0125984019, 0....
# 4      [0.0771951079, 0.027206542, -0.0130433952, -0....
# ...                                                  ...
# 25223  [-0.0677532032, 0.0909031257, -0.011235184, 0....
# 25224  [-0.0339421257, 0.0858471021, -0.012784712, 0....
# 25225  [-0.0447881632, 0.1195616573, -0.0072561293000...
# 25226  [-0.1070504785, -0.1365594715, -0.0100096073, ...
# 25227  [-0.0323677883, 0.0826153681, -0.0100744274, -...
#
#                                               train_word  \
# 0      種瓜得瓜 AI也略懂略懂生活科技資料 數字 Bottou AI 數據 顏色虛假相關 因果關係...
# 1      眼見不為憑：假新聞攻防戰生活科技影片 Deepfake 影像 資料 AI 假消息對抗生成網路...
# 2      演化，AI的第三條路！(1/2)生活科技遺傳 函數 規劃 電路 控制器 演化基因 機器學習 ...
# 3      理解與預測：科學的兩條路生活科技一個 預測 理解 科學 人類 之間人工智慧 康德 中文房間 ...
# 4      別中了社群媒體的圈套(2/2)生活科技多巴胺 媒體 社群 手機 釋放 使用者打卡 倫理 多巴...
# ...                                                  ...
# 25223  利比亞重奪油港、出口恐增，油價再添壓力環境能源利比亞 OPEC 14 萬桶 減產 石油輸出國...
# 25224  解決缺電雙管齊下，經濟部：核二廠備而不用環境能源核二廠 供電 號機 格架案 報告 核二廠 1...
# 25225  住宅太陽能夯！SunPower 推用戶貸款案 股價創 09 年高環境能源太陽能 貸款 Sun...
# 25226  矽晶圓和電池報價破底，太陽能產業現陰霾環境能源太陽能 報價 中國 矽晶圓 amp 隨著中國太...
# 25227  太陽能 ETF 飆近 5 年高！儲能爆發，今年綠能將供美 1/5 用電環境能源太陽能 儲能 ...
#
#                                                   vector  \
# 0      [-0.0583782196, 0.1031238064, -0.0113756964000...
# 1      [0.043455038200000004, 0.060704663400000004, -...
# 2      [0.0225472897, 0.0992054567, -0.0078522237, -0...
# 3      [0.0686305091, 0.0514615625, -0.0094612828, -0...
# 4      [0.1136551425, 0.0289493725, -0.012286108, -0....
# ...                                                  ...
# 25223  [-0.039790824100000004, 0.008907675700000001, ...
# 25224  [-0.0116125308, 0.08935615420000001, -0.014415...
# 25225  [-0.037492018200000005, 0.1061695144, -0.00896...
# 25226  [-0.09039378170000001, -0.1806803197, -0.01122...
# 25227  [-0.0194282606, -0.0997526571, -0.013165022200...
#
#                                             vector_title  \
# 0      [-0.0173872132, 0.11031571030000001, -0.016326...
# 1      [0.06334497780000001, 0.144509241, -0.01732851...
# 2      [0.0084472038, 0.153572455, -0.0110182399, -0....
# 3      [0.0314404219, 0.19583205880000001, -0.0118992...
# 4      [0.1116571501, 0.1034322381, -0.0180011783, 0....
# ...                                                  ...
# 25223  [-0.0216975473, -0.049634777000000005, -0.0142...
# 25224  [-0.0049787723, 0.1505208015, -0.0172369964, 0...
# 25225  [-0.0448014326, 0.0850963891, -0.0159920491, -...
# 25226  [-0.0100124273, -0.065633826, -0.0141598051, 0...
# 25227  [-0.0337350778, -0.11418613050000001, -0.01793...
#
#                                               vector_tag  \
# 0      [-0.0372301415, 0.2327384651, -0.0132301245, 0...
# 1      [0.0662990957, 0.129875198, -0.012187048800000...
# 2      [-0.0646500215, 0.22329041360000002, -0.008657...
# 3      [0.08189587300000001, 0.1672154069, -0.0134308...
# 4      [-0.005840742, 0.2770869434, -0.0137596214, -0...
# ...                                                  ...
# 25223             'NoneType' object is not subscriptable
# 25224             'NoneType' object is not subscriptable
# 25225             'NoneType' object is not subscriptable
# 25226             'NoneType' object is not subscriptable
# 25227             'NoneType' object is not subscriptable
#
#                                                vector_tf  \
# 0      [-0.148078233, 0.0561440252, -0.0104988152, 0....
# 1      [-0.0551759563, 0.0143376132, -0.0093437964, 0...
# 2      [-0.07414200160000001, 0.0640343577, -0.015786...
# 3      [0.0892356634, 0.2118693441, -0.01379486170000...
# 4      [0.0466845334, 0.0673067942, -0.0178314056, -0...
# ...                                                  ...
# 25223  [-0.10559444870000001, 0.051304854500000004, -...
# 25224  [0.0034979533, 0.1363986284, -0.0180752911, 0....
# 25225  [-0.0415744744, 0.08353496340000001, -0.013032...
# 25226  [-0.035629414000000005, -0.07000338290000001, ...
# 25227  [-0.014025541, 0.0538733564, -0.0211572647, -0...
#
#                             imgur_link
# 0      https://i.imgur.com/h22yHp7.png
# 1      https://i.imgur.com/wNiPWC2.png
# 2      https://i.imgur.com/ncpLQWD.png
# 3      https://i.imgur.com/MOoKflc.png
# 4      https://i.imgur.com/BKZ0XpL.png
# ...                                ...
# 25223                              NaN
# 25224                              NaN
# 25225                              NaN
# 25226                              NaN
# 25227                              NaN
#
# [25228 rows x 13 columns]

# %% [markdown]
# ### 轉換成文字雲

# %%
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import jieba

# %%
# Function to load stop words from the file
def load_stopwords(file_path):
    with open(file_path, "r", encoding="utf-8") as file:
        stopwords = set(file.read().split())
    return stopwords


# Load the DataFrame from JSON
loaddf = pd.read_json("vector_all.json")
print("Load DataFrame from JSON Done")

# Load Chinese stop words
stopwords_file = "stopwords_chinese.txt"
stopwords = load_stopwords(stopwords_file)
print("Load Chinese stop words Done")

# Generate a word cloud image
chinese_font_path = "jf-openhuninn-2.0.ttf"


def create_word_cloud(index, string):
    wordcloud = WordCloud(
        background_color="white",
        width=600,
        height=400,
        margin=2,
        font_path=chinese_font_path,
        prefer_horizontal=1,
        colormap="Set2",
        stopwords=stopwords,  # Pass the loaded stop words
    ).generate(string)
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    save_path = f"images/{index}.png"
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.clf()
    print(f"Create word cloud for {index} Done")

# Function to tokenize and remove stop words


def tokenize_and_remove_stopwords(string):
    words = jieba.cut(string)
    return " ".join(w for w in words if w not in stopwords)


print("Start to tokenize and remove stop words")

# Tokenize and remove stop words for the 'content' column
loaddf["jieba_cut"] = loaddf["content"].apply(
    lambda x: tokenize_and_remove_stopwords(x))

print("Tokenize and remove stop words Done")

# Now you can use the 'loaddf' DataFrame with the 'jieba_cut' column, which contains the tokenized content without Chinese stop words.

print("Start to create word cloud")
loaddf.apply(lambda x: create_word_cloud(x.name, x["jieba_cut"]), axis=1)
print("Create word cloud Done")

# %% [markdown]
# ---

# %% [markdown]
# ### Save Data

# %%
from pymongo import MongoClient

# 建立 MongoDB 連線
client = MongoClient("mongodb://100.90.12.119:27017/")
db = client.nthu_trello_helper
mongo_collection = db.article

# %%
from pymilvus import DataType, FieldSchema, CollectionSchema, Collection, connections
# 設定 Milvus 的連線資訊
connections.connect(alias="default")

# 設定 Milvus collection 名稱和維度
collection_name = 'trello_finder'
# 設定分區名稱
partition_name = 'import'

# %%
milvus_collection = Collection(collection_name)

# %%
errorlist = []

# %%
# 將資料存入 MongoDB
for idx, row in df.iterrows():
    try:
        # 插入 MongoDB
        mongo_collection.insert_one({
            "link_id": str(idx),
            "title": row["title"],
            "url": row["url"],
            "content": row["content"],
            "importMilvus": True,
            "values": row["vector"],
            "class": row["class"],
            "tag": row["tag"],
            "tf": row["TF"],
        })

    except Exception as exp:
        print("MongoDB Insert Fail")
        print(exp)
        errorlist.append(idx)

# %%
# 將資料存入 Milvus
for idx, row in df.iterrows():
    try:

        insert_milvus_title = row["title"]
        if (len(insert_milvus_title) > 500):
            insert_milvus_title = insert_milvus_title[:497] + "..."

        try:
            # 插入 Milvus
            status = milvus_collection.insert({
                "id": str(idx),
                "track_id": str(idx),
                "value": row["vector_tf"],
                "title": insert_milvus_title,
            }, partition_name=partition_name)

            if (status.insert_count != 1):
                print("Milvus Insert Fail")
                print(status)
                errorlist.append(idx)
            # else:
                # print("Done \n--------")

        except Exception as exp:
            print("--------------------")
            print(str(idx), "|", len(str(idx)))
            print("Vector |", len(row["vector"]))
            print(insert_milvus_title, "|", len(insert_milvus_title))
            print("--------------------")
            print("Milvus Insert Fail")
            print(exp)
            errorlist.append(idx)

    except Exception as exp:
        print("MongoDB Insert Fail")
        print(exp)
        errorlist.append(idx)
# Out:
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.029217', 'RPC error': '2023-08-02 20:57:01.029217'}>
# --------------------
# 8370 | 4
# Vector | 768
# 以假亂真，虛實難辨—虛擬實境 | 14
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.248869', 'RPC error': '2023-08-02 20:57:01.248869'}>
# --------------------
# 8432 | 4
# Vector | 768
# 您所不知道的諾貝爾物理 | 11
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.750078', 'RPC error': '2023-08-02 20:57:01.750078'}>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.811520', 'RPC error': '2023-08-02 20:57:01.811520'}>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.812520', 'RPC error': '2023-08-02 20:57:01.812520'}>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.812520', 'RPC error': '2023-08-02 20:57:01.812520'}>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:01.813840', 'RPC error': '2023-08-02 20:57:01.813840'}>
# --------------------
# 8576 | 4
# Vector | 768
# 看見微小世界（電子顯微鏡） | 13
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# --------------------
# 8591 | 4
# Vector | 768
# 『一家一枚 』科學海報：量子光學 | 16
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# --------------------
# 8592 | 4
# Vector | 768
# 什麼是暗物質與暗能量？ | 11
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# --------------------
# 8593 | 4
# Vector | 768
# 1901-1966年諾貝爾物理獎揭秘檔案 | 20
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# --------------------
# 8594 | 4
# Vector | 768
# 重力波大年表 | 6
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>
# RPC error: [insert_rows], <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>, <Time:{'RPC start': '2023-08-02 20:57:02.054212', 'RPC error': '2023-08-02 20:57:02.054212'}>
# --------------------
# 8660 | 4
# Vector | 768
# 科學女力：2018女物理人研討會紀實 | 18
# --------------------
# Milvus Insert Fail
# <ParamError: (code=1, message=Collection field dim is 768, but entities field dim is 38)>

# %%
errorlist

# %%
for idx, row in df.iloc[errorlist].iterrows():
    print(idx)
    insert_milvus_title = row["title"]
    if (len(insert_milvus_title) > 75):
        insert_milvus_title = insert_milvus_title[:71] + "..."
    print(len(insert_milvus_title))
    print(row["title"])

# %%
expr = 'id in ["21846","8591"]'
milvus_collection.delete(expr)
# Out:
# (insert count: 0, delete count: 2, upsert count: 0, timestamp: 443319007144312835, success count: 0, err count: 0)

# %% [markdown]
# ### TF 標籤輸出 (相似文字搜尋)

# %%
def search_keyword(keyword):
    # Replace NaN values with empty strings
    df['TF'] = df['TF'].fillna('')
    # Search for the keyword in the TF column
    results = df[df['TF'].str.contains(keyword)]['TF'].tolist()

    # Split the results into individual words and count their occurrences
    word_counts = {}
    for result in results:
        words = result.split()
        for word in words:
            word_counts[word] = word_counts.get(word, 0) + 1

    # Sort the words based on their occurrence count in descending order
    sorted_words = sorted(word_counts.keys(),
                          key=lambda x: word_counts[x], reverse=True)

    # Return the top 3 words
    if (len(sorted_words) > 3):
        sorted_words = sorted_words[:3]
    return sorted_words

# %%
input_keyword = "藍光"
output = search_keyword(input_keyword)
print(output)
# Out:
# ['藍光', 'LED', '中村']

# %%
def create_result_table(words_list):
    # 定義一個空的表格
    table_data = []
    # 定義一個空的錯誤列表
    errList = []
    # 逐一取出文字列表中的文字
    for word in words_list:
        try:
            # 將文字進行 search_keyword(文字) 並將結果存入 result
            result = search_keyword(word)
            # 將 word 和 result 存入表格中
            table_data.append({
                'word': word,
                'simliar_word': result,
            })
        except:
            # 如果有錯誤，將 word 存入錯誤列表中
            errList.append(word)
            continue

    # 將表格和錯誤列表回傳
    return {
        "data": table_data,
        "errList": errList,
    }


# 从 TF 列获取文字列表
words_list = df['TF'].str.split().explode().unique().tolist()

# 利用文字列表中的文字進行 search_keyword(文字) 并将结果输出成表格
result_table = create_result_table(words_list)
simliar_word_df = pd.DataFrame(result_table["data"]).fillna("")
# 將 simliar_word 列中的列表轉成字串
simliar_word_df["simliar_word_str"] = simliar_word_df["simliar_word"].apply(
    lambda x: " ".join(x))

# %%
simliar_word_df
# Out:
#          word       simliar_word simliar_word_str
# 0          資料      [資料, AI, 資料庫]        資料 AI 資料庫
# 1          數字       [數字, 一個, AI]         數字 一個 AI
# 2      Bottou   [資料, 數字, Bottou]     資料 數字 Bottou
# 3          AI     [AI, 人工智慧, 醫療]       AI 人工智慧 醫療
# 4          數據       [數據, AI, 疫苗]         數據 AI 疫苗
# ...       ...                ...              ...
# 23167      工學  [麻省理工學院, 團隊, 咳嗽聲]    麻省理工學院 團隊 咳嗽聲
# 23168     茨城縣      [輻射, 工學, 核燃料]        輻射 工學 核燃料
# 23169    本世紀內      [G7, amp, 國家]        G7 amp 國家
# 23170     利比亞    [利比亞, OPEC, 14]      利比亞 OPEC 14
# 23171     格架案      [核二廠, 供電, 號機]        核二廠 供電 號機
#
# [23172 rows x 3 columns]

# %%
from pymongo import MongoClient

# 建立 MongoDB 連線
client = MongoClient("mongodb://100.90.12.119:27017/")
db = client.nthu_trello_helper
mongo_collection = db.close_words

# %%
for idx, row in simliar_word_df.iterrows():
    # 插入 MongoDB
    mongo_collection.insert_one({
        "key": str(row['word']),
        "value": row['simliar_word_str']
    })

# %%
mongo_collection.insert_one({
    "key": "虎克定律",
    "value": "虎克定律 Hooke’s law 應力 應變 運動與力"
})
