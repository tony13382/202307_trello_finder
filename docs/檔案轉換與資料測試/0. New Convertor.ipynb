# %% [markdown]
# ### Basic Function

# %%
# 引入套件
import pandas as pd
import numpy as np

# %%
# Import modules
from sentence_transformers import SentenceTransformer, util
# Select model by transformer
# about model: https://huggingface.co/sentence-transformers/paraphrase-multilingual-mpnet-base-v2
sbert_model = SentenceTransformer('paraphrase-multilingual-mpnet-base-v2')
print('sbert_model loaded')

def embedding_sentence(sentence):
    try:
        return {
            "state" : True,
            "value" : sbert_model.encode(sentence).tolist(), # return a vector list
        }
    except Exception as exp:
        return {
            "state" : False,
            "value" : np.zeros(768)
        }

def convert_to_np_array(lst):
    # 檢查 lst 是否為 None 或為具有值的列表
    if lst is None:
        return np.zeros(768)
    elif isinstance(lst, list):
        return np.array(lst)
    else:
        return np.zeros(768)

def calc_array_mean(input_set, len_array):
    # Define weight that needs to sum
    sum_weight = 0
    # Define sum_array to sum all arrays
    sum_array = np.zeros(len_array)
    for item in input_set:
        item['array'] = np.array(item['array'])  # Convert to NumPy array
        # Check if the array is empty
        if item['array'].sum() == 0:
            # Don't calculate this weight
            sum_weight += 0
        else:
            # Calculate this weight
            sum_weight += item['weight']
            # Add to sum_array
            sum_array += item['array'] * item['weight']

    return sum_array / sum_weight

# Import modules of MongoDB
from pymongo import MongoClient
from pymongo.errors import InvalidOperation
# Import modules of datetime(For Log)
from datetime import datetime,timezone,timedelta
# Setup environment value
import os
from dotenv import load_dotenv
load_dotenv()
mongodb_path = os.getenv("mongodb_path")
mongodb_username = os.getenv("mongodb_username")  # 替換為你的用戶名
mongodb_password = os.getenv("mongodb_password")  # 替換為你的密碼

# 建立 MongoDB 連線
client = MongoClient(mongodb_path, username=mongodb_username, password=mongodb_password)
db = client.nthu_trello_helper
mongo_article_collection = db.article
mongo_trello_log_collection = db.trello_log
mongo_word_injection_collection = db.injection_list
mongo_keyword_collection = db.keyword
mongo_keyword_record_collection = db.keyword_record

#article_df = []
#milvus_df = []
#kr_df = []

import re
import monpa
monpa.load_userdict("../../setting/MONPA_斷詞字典.txt")
print('monpa_dict loaded')

# 讀取文字檔並轉換成串列
def txt_to_list(file_path):
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            content = file.readlines()
            content = [line.strip() for line in content]
        return content
    except FileNotFoundError:
        print("找不到指定的檔案。請檢查檔案路徑是否正確。", file_path)
        return []
    except Exception as e:
        print("讀取檔案時發生錯誤：", e)
        return []


# 指定文字檔路徑
stop_word_list = txt_to_list("../../setting/stopwords_chinese.txt")
print('stop_word_list loaded')

def cutSentence(sentence):
    seg = []
    for item in sentence.split("，"):
        if item != "\n":
            seg.extend(monpa.cut(str(item+"，")))

    word_list = seg[:-1]

    word_list = [word for word in word_list if word not in stop_word_list]
    # 将词列表拼接成句子
    sentence = ' '.join(word_list)
    return sentence
import re
from collections import Counter
def calculate_word_frequency(row, text):
    df_array = []
    words = re.findall(r'\b\w+\b', text)  # 利用正則表達式分割文本成單詞
    word_freq = Counter(words)  # 計算字詞的字頻
    total_words = len(words)  # 總字詞數

    # 計算每個字的tf
    word_tf = {word: word_freq[word] / total_words for word in word_freq}

    # 將結果轉換成指定的格式
    result = [{"article": row, "word": word, "count": word_freq[word],
               "tf": word_tf[word]} for word in word_freq if word_freq[word] > 1]
    df_array.extend(result)
    return df_array
def get_new_article_id():
    # 执行聚合查询以找到linked_id字段的最大值
    # 使用聚合查询将文本字段转换为数字并找到最大值
    pipeline = [
        {
            "$project": {
                "link_id_numeric": {
                    "$convert": {
                        "input": "$link_id",
                        "to": "int",
                        "onError": 0  # 如果转换失败，将使用0作为默认值
                    }
                }
            }
        },
        {
            "$group": {
                "_id": None,
                "maxLinkIdNumeric": { "$max": "$link_id_numeric" }
            }
        }
    ]

    try:
        result = list(mongo_article_collection.aggregate(pipeline))
        if result:
            max_linked_id_numeric = result[0]["maxLinkIdNumeric"]
            #print(f"最大的link_id数值是: {max_linked_id_numeric}")
            return (max_linked_id_numeric+1)
        else:
            print("没有找到可转换为数值的linked_id值。")
            return 0
    except InvalidOperation as e:
        print(f"无法进行转换或聚合操作: {e}")
        return 0
def get_new_keyword_id():
    # 执行聚合查询以找到linked_id字段的最大值
    # 使用聚合查询将文本字段转换为数字并找到最大值
    pipeline = [
        {
            "$project": {
                "link_id_numeric": {
                    "$convert": {
                        "input": "$link_id",
                        "to": "int",
                        "onError": 0  # 如果转换失败，将使用0作为默认值
                    }
                }
            }
        },
        {
            "$group": {
                "_id": None,
                "maxLinkIdNumeric": { "$max": "$link_id_numeric" }
            }
        }
    ]

    try:
        result = list(mongo_keyword_collection.aggregate(pipeline))
        if result:
            max_linked_id_numeric = result[0]["maxLinkIdNumeric"]
            #print(f"最大的link_id数值是: {max_linked_id_numeric}")
            return (max_linked_id_numeric+1)
        else:
            print("没有找到可转换为数值的linked_id值。")
            return -1
    except InvalidOperation as e:
        print(f"无法进行转换或聚合操作: {e}")
        return -1
def get_article_id(article_title):
    # 搜尋關鍵字 ID
    result = mongo_article_collection.find_one({
        "title": article_title
    })
    if result is not None:
        return result["link_id"]
def get_kw_id(kw_string):
    # 搜尋關鍵字 ID
    result = mongo_keyword_collection.find_one({
        "preview_str": kw_string
    })
    if result is not None:
        return result["link_id"]
    else:
        # Import modules of Milvus
        from pymilvus import connections, Collection, utility
        # Setup environment value
        import os
        from dotenv import load_dotenv
        load_dotenv()
        milvus_path = os.getenv("milvus_path")
        milvus_port = os.getenv("milvus_port")
        milvus_db_name = os.getenv("milvus_db_name")

        # Connect to milvus server (connector)
        conn = connections.connect(
            alias="default",
            host=milvus_path,
            port=milvus_port,
            db_name=milvus_db_name
        )

        # 設定 Milvus collection 名稱
        # 建立 collection
        collection = Collection("trello_finder_keyword")
        #======================== env done ==========================#

        new_kw_id = str(get_new_keyword_id())
        kw_vector = embedding_sentence(kw_string)["value"]
        mongo_keyword_collection.insert_one({
            "link_id": new_kw_id,
            "vector": kw_vector,
            "preview_str": kw_string,
        })

        status = collection.insert({
            "keyword_id": new_kw_id,
            "link_id": new_kw_id,
            "vector": kw_vector,
            "preview_str": kw_string,
        }, partition_name = MILVUS_KEYWORD_PART)

        if (status.insert_count != 1):
            print("Insert failed!")
            return False
        else:
            return new_kw_id

from pymilvus import DataType, FieldSchema, CollectionSchema, Collection, connections

MONGO_FROM_TEXT = "_data"
MILVUS_ARTICLE_PART = 'import'
MILVUS_KEYWORD_PART = "import"
# Out:
# 11/04/2023 13:15:38 - INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: paraphrase-multilingual-mpnet-base-v2
# 11/04/2023 13:15:40 - INFO - sentence_transformers.SentenceTransformer - Use pytorch device: cpu
# sbert_model loaded
# monpa_dict loaded
# stop_word_list loaded

# %%
def insert_to_mongo(article_id, title, url, content, vector):
    try:
        monpa_str = (title + ' ')*10 + content
        # 提取字頻和tf
        corpus = cutSentence(monpa_str)
        # 插入 MongoDB
        mongo_data = {
            "link_id": article_id,
            "title": title,
            "url": url,
            "content": content,
            "values": vector,
            "cuted" : corpus,
            "form" : MONGO_FROM_TEXT
        }
        #global article_df  # 声明使用外部的 article_df
        #article_df.append(mongo_data)
        mongo_article_collection.insert_one(mongo_data)
        return True
    except Exception as exp:
        print("MongoDB Insert Fail")
        print(exp)
        return False

def insert_to_milvus(article_id, article_title, vectors_to_search):
    # 設定 Milvus 的連線資訊
    # +------------------------------+ #
    # 設定 Milvus collection 名稱和維度
    collection_name = 'trello_finder_v2'
    # +------------------------------+ #
    connections.connect(alias="default")
    milvus_collection = Collection(collection_name)
    
    try:
        insert_milvus_title = article_title
        if (len(insert_milvus_title) > 50):
            insert_milvus_title = insert_milvus_title[:47] + "..."

        try:
            milvus_data = {
                "id": article_id,
                "track_id": article_id,
                "value": vectors_to_search,
                "title": insert_milvus_title,
            }
            #global milvus_df  # 声明使用外部的 article_df
            #milvus_df.append(milvus_data)


            # 插入 Milvus
            status = milvus_collection.insert(milvus_data, partition_name=MILVUS_ARTICLE_PART)

            if (status.insert_count != 1):
                print("Milvus Insert Fail")
                print(status)
                return False
            return True

        except Exception as exp:
            print("--------------------")
            #print(article_id, "|", len(article_id))
            print("Vector |", len(vectors_to_search))
            print(insert_milvus_title, "|", len(insert_milvus_title))
            print("--------------------")
            print("Milvus Insert Fail")
            print(exp)
            return False

    except Exception as exp:
        print("Milvus Insert Fail")
        print(exp)
        return False

def insert_to_kr(article_id, article_title, article_content):
    try:
        monpa_str = (article_title + ' ')*10 + article_content
        
        # 提取字頻和tf
        corpus = cutSentence(monpa_str)
        kw_list = calculate_word_frequency(article_id, corpus)

        for item in kw_list:
            kr_data = {
                "article_id" : article_id,
                "keyword_id" : get_kw_id(item["word"]),
                "tf_value" : item["tf"],
                "count" : item["count"],
                "score" : item["tf"] * item["count"]
            }
            #global kr_df  # 声明使用外部的 article_df
            #kr_df.append(kr_data)
            
            mongo_keyword_record_collection.insert_one(kr_data)
        
        return True
    except Exception as e:
        print(e)
        return False

# %%
# 將文章的資料引入
def add_article(article_content,article_title,article_url,article_tag="", content_vector=[], title_vector=[]):
    
    if article_content != "":
        if len(content_vector) == 0:
            vector_content = embedding_sentence(article_content)["value"]
        else:
            vector_content = content_vector
    else:
        return {
            "state" : False,
            "msg" : "article_content is null"
        }
    if article_title != "":
        if len(title_vector) == 0:
            vector_title = embedding_sentence(article_title)["value"]
        else:
            vector_title = title_vector
    else:
        return {
            "state" : False,
            "msg" : "article_title is null"
        }
    if article_url == "":
        return {
            "state" : False,
            "msg" : "article_url is null"
        }
    if article_tag != "":
        vector_tag = embedding_sentence(article_tag)["value"]
    else:
        noTag = True


    weights = [3, 1]  # 根据你的要求定义权重
    vectors_to_calc = [np.array(vector_title), np.array(vector_content)]
    
    sum_weight = sum(weights)
    weighted_sum = sum(w * v for w, v in zip(weights, vectors_to_calc))
    vectors_to_search = weighted_sum / sum_weight

    new_article_id = str(get_new_article_id())

    # Insert to mongodb
    toMongo = insert_to_mongo(new_article_id, article_title, article_url, article_content, vectors_to_search.tolist())
    if toMongo is False:
        return {
            "state" : False,
            "msg" : "tomongo error"
        }

    # Insert to Milvus
    toMilvus = insert_to_milvus(new_article_id, article_title, vectors_to_search.tolist())
    if toMilvus is False:
        return {
            "state" : False,
            "msg" : "to milvus error"
        }

    toKr = insert_to_kr(new_article_id,article_title,article_content)
    if toKr is False:
        return {
            "state" : False,
            "msg" : "to keyrecord error"
        }
    
    return {
        "state" : True,
        "msg" : "Yes"
    }

# %% [markdown]
# ### Read Article
# require : `title` , `content` , `url` , `vector_title[768]` , `vector_content[768]`

# %%
df = pd.read_json("../backup/vector_all.json")

# %%
df.iloc[0]
# Out:
# class                                                            數學
# title             微積分初階－歷史發展的眼光（9）萊布尼茲從差和分連續化得到微積分（First Course ...
# tag                                 積分 無窮小量 微積分 微分 和分 數學 差分 微積分根本定理
# TF                                  無窮 dx 微積分 積分 Delta displaystyle
# url               https://highscope.ch.ntu.edu.tw/wordpress/?p=1...
# content           微積分初階－歷史發展的眼光（9）萊布尼茲從差和分連續化得到微積分（First Course ...
# vector_content    [-0.1001347452, 0.06442421670000001, -0.009284...
# train_word        微積分初階－歷史發展的眼光（9）萊布尼茲從差和分連續化得到微積分（First Course ...
# vector            [-0.1342700869, 0.038052819700000004, -0.00888...
# vector_title      [-0.1260712594, 0.0393261835, -0.0068134414, 0...
# vector_tag        [-0.0099172266, -0.0680422038, -0.016843661700...
# vector_tf         [-0.1165701821, -0.1580965668, -0.0129927788, ...
# Name: 2562, dtype: object

# %% [markdown]
# Setting Save tag for mongodb and milvus partition_name

# %%
MONGO_FROM_TEXT = "Pansci_data"
MILVUS_ARTICLE_PART = 'import_pansci'
MILVUS_KEYWORD_PART = "import_pansci"

# %%
df_size = len(df)
for index, row in df.iterrows():
    step = add_article(
        row["content"],
        row["title"],
        row["url"],
        content_vector= row["vector_content"],
        title_vector= row["vector_title"],
    )
    if step["state"] is False:
        print(index,"/",df_size)
        break
# Out:
# 没有找到可转换为数值的linked_id值。
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.15it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.08it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.15it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.77it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.77it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 27.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.11it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 46.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 27.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 21.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 28.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.11it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 26.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.15it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.77it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.11it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.08it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.08it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.08it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.11it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 23.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.15it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.96it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 27.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.30it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 20.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.03it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.12it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.89it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.31it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.92it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.08it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 27.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.94it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.87it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 25.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.81it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.60it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.49it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 33.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.22it/s]
# ...
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 46.11it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 28.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.39it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.74it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.88it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.14it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.27it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.34it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.95it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.73it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.82it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.57it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.58it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.42it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.19it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.13it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.07it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.52it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.91it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 19.59it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.84it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.72it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.02it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.33it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.29it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.64it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 36.22it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 31.25it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.38it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.50it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.32it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.35it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.17it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 14.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.63it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 37.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.62it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.23it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.24it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.68it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.28it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.16it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 24.04it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 44.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.44it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.01it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.09it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.83it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.97it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 32.26it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 46.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.20it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.56it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.69it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.54it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.78it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 12.80it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.93it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.05it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.65it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 38.36it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.40it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.75it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 34.48it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.99it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.06it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.85it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.67it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.43it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 35.76it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.90it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.98it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.21it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.53it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.71it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.61it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.47it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.18it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.51it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.37it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.79it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 39.10it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 41.66it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.86it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 45.45it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.70it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 42.41it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.00it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 46.55it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 43.46it/s]
# Batches: 100%|██████████| 1/1 [00:00<00:00, 40.85it/s]

# %% [markdown]
# ### Delete Data by Index

# %%
# 設定 Milvus collection 名稱和維度
collection_name = 'trello_finder_v2'
# +------------------------------+ #
connections.connect(alias="default")
milvus_collection = Collection(collection_name)

for i in range(25228,30988,1):
    expr = f'id in ["{i}"]'
    #print(expr)
    milvus_collection.delete(expr)

# %%
# Delete Keyword Record
for i in range(25228,30988,1):
    result = mongo_keyword_record_collection.delete_many({"article_id": f"{i}"})
    if result.deleted_count > 0:
        print(f"{result.deleted_count} documents deleted successfully.")
# Out:
# 491 documents deleted successfully.
# 135 documents deleted successfully.
# 190 documents deleted successfully.
# 88 documents deleted successfully.
# 413 documents deleted successfully.
# 353 documents deleted successfully.
# 236 documents deleted successfully.
# 87 documents deleted successfully.
# 53 documents deleted successfully.
# 199 documents deleted successfully.
# 434 documents deleted successfully.
# 172 documents deleted successfully.
# 391 documents deleted successfully.
# 596 documents deleted successfully.
# 51 documents deleted successfully.
# 1071 documents deleted successfully.
# 579 documents deleted successfully.
# 108 documents deleted successfully.
# 450 documents deleted successfully.
# 63 documents deleted successfully.
# 192 documents deleted successfully.
# 558 documents deleted successfully.
# 43 documents deleted successfully.
# 41 documents deleted successfully.
# 118 documents deleted successfully.
# 117 documents deleted successfully.
# 529 documents deleted successfully.
# 618 documents deleted successfully.
# 58 documents deleted successfully.
# 269 documents deleted successfully.
# 188 documents deleted successfully.
# 666 documents deleted successfully.
# 703 documents deleted successfully.
# 412 documents deleted successfully.
# 570 documents deleted successfully.
# 64 documents deleted successfully.
# 304 documents deleted successfully.
# 50 documents deleted successfully.
# 579 documents deleted successfully.
# 51 documents deleted successfully.
# 171 documents deleted successfully.
# 113 documents deleted successfully.
# 541 documents deleted successfully.
# 46 documents deleted successfully.
# 326 documents deleted successfully.
# 131 documents deleted successfully.
# 39 documents deleted successfully.
# 496 documents deleted successfully.
# 491 documents deleted successfully.
# 172 documents deleted successfully.
# 440 documents deleted successfully.
# 297 documents deleted successfully.
# 221 documents deleted successfully.
# 69 documents deleted successfully.
# 563 documents deleted successfully.
# 210 documents deleted successfully.
# 184 documents deleted successfully.
# 62 documents deleted successfully.
# 53 documents deleted successfully.
# 201 documents deleted successfully.
# 477 documents deleted successfully.
# 75 documents deleted successfully.
# 584 documents deleted successfully.
# 218 documents deleted successfully.
# 463 documents deleted successfully.
# 443 documents deleted successfully.
# 191 documents deleted successfully.
# 519 documents deleted successfully.
# 216 documents deleted successfully.
# 746 documents deleted successfully.
# 459 documents deleted successfully.
# 39 documents deleted successfully.
# 51 documents deleted successfully.
# 498 documents deleted successfully.
# 527 documents deleted successfully.
# 10 documents deleted successfully.
# 223 documents deleted successfully.
# 172 documents deleted successfully.
# 673 documents deleted successfully.
# 200 documents deleted successfully.
# 271 documents deleted successfully.
# 78 documents deleted successfully.
# 100 documents deleted successfully.
# 304 documents deleted successfully.
# 45 documents deleted successfully.
# 369 documents deleted successfully.
# 279 documents deleted successfully.
# 168 documents deleted successfully.
# 542 documents deleted successfully.
# 73 documents deleted successfully.
# 591 documents deleted successfully.
# 66 documents deleted successfully.
# 69 documents deleted successfully.
# 158 documents deleted successfully.
# 780 documents deleted successfully.
# 293 documents deleted successfully.
# 11 documents deleted successfully.
# 312 documents deleted successfully.
# 637 documents deleted successfully.
# 206 documents deleted successfully.
# 463 documents deleted successfully.
# 183 documents deleted successfully.
# 52 documents deleted successfully.
# 76 documents deleted successfully.
# 56 documents deleted successfully.
# 41 documents deleted successfully.
# 239 documents deleted successfully.
# 40 documents deleted successfully.
# 216 documents deleted successfully.
# 56 documents deleted successfully.
# 82 documents deleted successfully.
# 117 documents deleted successfully.
# 648 documents deleted successfully.
# 122 documents deleted successfully.
# 244 documents deleted successfully.
# 84 documents deleted successfully.
# 251 documents deleted successfully.
# 33 documents deleted successfully.
# 566 documents deleted successfully.
# 54 documents deleted successfully.
# 640 documents deleted successfully.
# 194 documents deleted successfully.
# 22 documents deleted successfully.
# 310 documents deleted successfully.
# 980 documents deleted successfully.
# 66 documents deleted successfully.
# 184 documents deleted successfully.
# 226 documents deleted successfully.
# 34 documents deleted successfully.
# 547 documents deleted successfully.
# 314 documents deleted successfully.
# 334 documents deleted successfully.
# 634 documents deleted successfully.
# 266 documents deleted successfully.
# 263 documents deleted successfully.
# 506 documents deleted successfully.
# 138 documents deleted successfully.
# 187 documents deleted successfully.
# 494 documents deleted successfully.
# 372 documents deleted successfully.
# 138 documents deleted successfully.
# 291 documents deleted successfully.
# 76 documents deleted successfully.
# 226 documents deleted successfully.
# 830 documents deleted successfully.
# 730 documents deleted successfully.
# 237 documents deleted successfully.
# 610 documents deleted successfully.
# 297 documents deleted successfully.
# 367 documents deleted successfully.
# 66 documents deleted successfully.
# 369 documents deleted successfully.
# 117 documents deleted successfully.
# 780 documents deleted successfully.
# 244 documents deleted successfully.
# 60 documents deleted successfully.
# 172 documents deleted successfully.
# 93 documents deleted successfully.
# 116 documents deleted successfully.
# 503 documents deleted successfully.
# 248 documents deleted successfully.
# 80 documents deleted successfully.
# 244 documents deleted successfully.
# 447 documents deleted successfully.
# 228 documents deleted successfully.
# 634 documents deleted successfully.
# 190 documents deleted successfully.
# 187 documents deleted successfully.
# 550 documents deleted successfully.
# 257 documents deleted successfully.
# 373 documents deleted successfully.
# 608 documents deleted successfully.
# 27 documents deleted successfully.
# 268 documents deleted successfully.
# 44 documents deleted successfully.
# 166 documents deleted successfully.
# 254 documents deleted successfully.
# 480 documents deleted successfully.
# 91 documents deleted successfully.
# 264 documents deleted successfully.
# 26 documents deleted successfully.
# 42 documents deleted successfully.
# 211 documents deleted successfully.
# 83 documents deleted successfully.
# 200 documents deleted successfully.
# 83 documents deleted successfully.
# 28 documents deleted successfully.
# 28 documents deleted successfully.
# 1302 documents deleted successfully.
# 171 documents deleted successfully.
# 290 documents deleted successfully.
# 281 documents deleted successfully.
# 573 documents deleted successfully.
# 96 documents deleted successfully.
# 102 documents deleted successfully.
# 46 documents deleted successfully.
# 305 documents deleted successfully.
# 172 documents deleted successfully.
# 407 documents deleted successfully.
# 294 documents deleted successfully.
# 36 documents deleted successfully.
# 252 documents deleted successfully.
# 466 documents deleted successfully.
# 44 documents deleted successfully.
# 315 documents deleted successfully.
# 224 documents deleted successfully.
# 238 documents deleted successfully.
# 322 documents deleted successfully.
# 147 documents deleted successfully.
# 197 documents deleted successfully.
# 379 documents deleted successfully.
# 41 documents deleted successfully.
# 334 documents deleted successfully.
# 44 documents deleted successfully.
# 74 documents deleted successfully.
# 71 documents deleted successfully.
# 185 documents deleted successfully.
# 22 documents deleted successfully.
# 147 documents deleted successfully.
# 485 documents deleted successfully.
# 129 documents deleted successfully.
# 684 documents deleted successfully.
# 85 documents deleted successfully.
# 304 documents deleted successfully.
# 286 documents deleted successfully.
# 48 documents deleted successfully.
# 170 documents deleted successfully.
# 530 documents deleted successfully.
# 471 documents deleted successfully.
# 513 documents deleted successfully.
# 175 documents deleted successfully.
# 169 documents deleted successfully.
# 58 documents deleted successfully.
# 87 documents deleted successfully.
# 375 documents deleted successfully.
# 175 documents deleted successfully.
# 54 documents deleted successfully.
# 208 documents deleted successfully.
# 540 documents deleted successfully.
# 196 documents deleted successfully.
# 444 documents deleted successfully.
# 60 documents deleted successfully.
# 213 documents deleted successfully.
# 58 documents deleted successfully.
# 203 documents deleted successfully.
# 226 documents deleted successfully.
# 550 documents deleted successfully.
# 375 documents deleted successfully.
# 548 documents deleted successfully.
# 54 documents deleted successfully.
# 53 documents deleted successfully.
# 239 documents deleted successfully.
# 33 documents deleted successfully.
# 517 documents deleted successfully.
# 518 documents deleted successfully.
# 64 documents deleted successfully.
# 343 documents deleted successfully.
# 236 documents deleted successfully.
# 571 documents deleted successfully.
# 55 documents deleted successfully.
# 48 documents deleted successfully.
# 208 documents deleted successfully.
# 146 documents deleted successfully.
# 76 documents deleted successfully.
# 346 documents deleted successfully.
# 115 documents deleted successfully.
# 669 documents deleted successfully.
# 1177 documents deleted successfully.
# 525 documents deleted successfully.
# 654 documents deleted successfully.
# 447 documents deleted successfully.
# 59 documents deleted successfully.
# 393 documents deleted successfully.
# 323 documents deleted successfully.
# 629 documents deleted successfully.
# 156 documents deleted successfully.
# 280 documents deleted successfully.
# 119 documents deleted successfully.
# 351 documents deleted successfully.
# 159 documents deleted successfully.
# 524 documents deleted successfully.
# 1120 documents deleted successfully.
# 1073 documents deleted successfully.
# 146 documents deleted successfully.
# 45 documents deleted successfully.
# 114 documents deleted successfully.
# 109 documents deleted successfully.
# 30 documents deleted successfully.
# 30 documents deleted successfully.
# 608 documents deleted successfully.
# 791 documents deleted successfully.
# 157 documents deleted successfully.
# 919 documents deleted successfully.
# 380 documents deleted successfully.
# 80 documents deleted successfully.
# 63 documents deleted successfully.
# 597 documents deleted successfully.
# 547 documents deleted successfully.
# 463 documents deleted successfully.
# 57 documents deleted successfully.
# 85 documents deleted successfully.
# 205 documents deleted successfully.
# 477 documents deleted successfully.
# 764 documents deleted successfully.
# 165 documents deleted successfully.
# 1101 documents deleted successfully.
# 162 documents deleted successfully.
# 716 documents deleted successfully.
# 132 documents deleted successfully.
# 337 documents deleted successfully.
# 33 documents deleted successfully.
# 451 documents deleted successfully.
# 695 documents deleted successfully.
# 639 documents deleted successfully.
# 29 documents deleted successfully.
# 643 documents deleted successfully.
# 390 documents deleted successfully.
# 258 documents deleted successfully.
# 656 documents deleted successfully.
# 159 documents deleted successfully.
# 149 documents deleted successfully.
# 131 documents deleted successfully.
# 254 documents deleted successfully.
# 166 documents deleted successfully.
# 418 documents deleted successfully.
# 86 documents deleted successfully.
# 139 documents deleted successfully.
# 530 documents deleted successfully.
# 401 documents deleted successfully.
# 123 documents deleted successfully.
# 83 documents deleted successfully.
# 351 documents deleted successfully.
# 274 documents deleted successfully.
# 274 documents deleted successfully.
# 470 documents deleted successfully.
# 274 documents deleted successfully.
# 595 documents deleted successfully.
# 47 documents deleted successfully.
# 244 documents deleted successfully.
# 33 documents deleted successfully.
# 54 documents deleted successfully.
# 38 documents deleted successfully.
# 779 documents deleted successfully.
# 363 documents deleted successfully.
# 81 documents deleted successfully.
# 49 documents deleted successfully.
# 905 documents deleted successfully.
# 248 documents deleted successfully.
# 325 documents deleted successfully.
# 376 documents deleted successfully.
# 314 documents deleted successfully.
# 139 documents deleted successfully.
# 49 documents deleted successfully.
# 593 documents deleted successfully.
# 76 documents deleted successfully.
# 157 documents deleted successfully.
# 52 documents deleted successfully.
# 122 documents deleted successfully.
# 58 documents deleted successfully.
# 373 documents deleted successfully.
# 28 documents deleted successfully.
# 670 documents deleted successfully.
# 557 documents deleted successfully.
# 314 documents deleted successfully.
# 444 documents deleted successfully.
# 196 documents deleted successfully.
# 48 documents deleted successfully.
# 197 documents deleted successfully.
# 254 documents deleted successfully.
# 408 documents deleted successfully.
# 111 documents deleted successfully.
# 155 documents deleted successfully.
# 73 documents deleted successfully.
# 188 documents deleted successfully.
# 235 documents deleted successfully.
# 391 documents deleted successfully.
# 894 documents deleted successfully.
# 118 documents deleted successfully.
# 57 documents deleted successfully.
# 72 documents deleted successfully.
# 435 documents deleted successfully.
# 427 documents deleted successfully.
# 175 documents deleted successfully.
# 263 documents deleted successfully.
# 203 documents deleted successfully.
# 47 documents deleted successfully.
# 342 documents deleted successfully.
# 536 documents deleted successfully.
# 225 documents deleted successfully.
# 377 documents deleted successfully.
# 244 documents deleted successfully.
# 677 documents deleted successfully.
# 212 documents deleted successfully.
# 33 documents deleted successfully.
# 342 documents deleted successfully.
# 179 documents deleted successfully.
# 408 documents deleted successfully.
# 424 documents deleted successfully.
# 78 documents deleted successfully.
# 171 documents deleted successfully.
# 710 documents deleted successfully.
# 70 documents deleted successfully.
# 751 documents deleted successfully.
# 30 documents deleted successfully.
# 472 documents deleted successfully.
# 243 documents deleted successfully.
# 265 documents deleted successfully.
# 55 documents deleted successfully.
# 321 documents deleted successfully.
# 141 documents deleted successfully.
# 192 documents deleted successfully.
# 682 documents deleted successfully.
# 495 documents deleted successfully.
# 62 documents deleted successfully.
# 460 documents deleted successfully.
# 46 documents deleted successfully.
# 487 documents deleted successfully.
# 138 documents deleted successfully.
# 58 documents deleted successfully.
# 155 documents deleted successfully.
# 25 documents deleted successfully.
# 28 documents deleted successfully.
# 266 documents deleted successfully.
# 69 documents deleted successfully.
# 186 documents deleted successfully.
# 303 documents deleted successfully.
# 428 documents deleted successfully.
# 210 documents deleted successfully.
# 472 documents deleted successfully.
# 247 documents deleted successfully.
# 162 documents deleted successfully.
# 205 documents deleted successfully.
# 739 documents deleted successfully.
# 43 documents deleted successfully.
# 631 documents deleted successfully.
# 434 documents deleted successfully.
# 57 documents deleted successfully.
# 159 documents deleted successfully.
# 373 documents deleted successfully.
# 359 documents deleted successfully.
# 669 documents deleted successfully.
# 179 documents deleted successfully.
# 479 documents deleted successfully.
# 111 documents deleted successfully.
# 470 documents deleted successfully.
# 187 documents deleted successfully.
# 122 documents deleted successfully.
# 417 documents deleted successfully.
# 542 documents deleted successfully.
# 181 documents deleted successfully.
# 154 documents deleted successfully.
# 41 documents deleted successfully.
# 713 documents deleted successfully.
# 363 documents deleted successfully.
# 182 documents deleted successfully.
# 748 documents deleted successfully.
# 440 documents deleted successfully.
# 18 documents deleted successfully.
# 40 documents deleted successfully.
# 191 documents deleted successfully.
# 35 documents deleted successfully.
# 379 documents deleted successfully.
# 319 documents deleted successfully.
# 477 documents deleted successfully.
# 162 documents deleted successfully.
# 29 documents deleted successfully.
# 156 documents deleted successfully.
# 58 documents deleted successfully.
# 219 documents deleted successfully.
# 670 documents deleted successfully.
# 491 documents deleted successfully.
# 61 documents deleted successfully.
# 237 documents deleted successfully.
# 202 documents deleted successfully.
# 71 documents deleted successfully.
# 248 documents deleted successfully.
# 456 documents deleted successfully.
# 29 documents deleted successfully.
# 32 documents deleted successfully.
# 223 documents deleted successfully.
# 1283 documents deleted successfully.
# 605 documents deleted successfully.
# 285 documents deleted successfully.
# 199 documents deleted successfully.
# 102 documents deleted successfully.
# 18 documents deleted successfully.
# 75 documents deleted successfully.
# 595 documents deleted successfully.
# 153 documents deleted successfully.
# 255 documents deleted successfully.
# 214 documents deleted successfully.
# 169 documents deleted successfully.
# 236 documents deleted successfully.
# 144 documents deleted successfully.
# 62 documents deleted successfully.
# 73 documents deleted successfully.
# 262 documents deleted successfully.
# 337 documents deleted successfully.
# 90 documents deleted successfully.
# 177 documents deleted successfully.
# 550 documents deleted successfully.
# 285 documents deleted successfully.
# 381 documents deleted successfully.
# 144 documents deleted successfully.
# 392 documents deleted successfully.
# 380 documents deleted successfully.
# 253 documents deleted successfully.
# 448 documents deleted successfully.
# 602 documents deleted successfully.
# 55 documents deleted successfully.
# 135 documents deleted successfully.
# 826 documents deleted successfully.
# 20 documents deleted successfully.
# 31 documents deleted successfully.
# 280 documents deleted successfully.
# 250 documents deleted successfully.
# 138 documents deleted successfully.
# 31 documents deleted successfully.
# 112 documents deleted successfully.
# 25 documents deleted successfully.
# 47 documents deleted successfully.
# 335 documents deleted successfully.
# 111 documents deleted successfully.
# 431 documents deleted successfully.
# 424 documents deleted successfully.
# 58 documents deleted successfully.
# 49 documents deleted successfully.
# 75 documents deleted successfully.
# 50 documents deleted successfully.
# 328 documents deleted successfully.
# 806 documents deleted successfully.
# 753 documents deleted successfully.
# 279 documents deleted successfully.
# 152 documents deleted successfully.
# 173 documents deleted successfully.
# 68 documents deleted successfully.
# 231 documents deleted successfully.
# 34 documents deleted successfully.
# 447 documents deleted successfully.
# 261 documents deleted successfully.
# 249 documents deleted successfully.
# 34 documents deleted successfully.
# 77 documents deleted successfully.
# 497 documents deleted successfully.
# 52 documents deleted successfully.
# 219 documents deleted successfully.
# 713 documents deleted successfully.
# 242 documents deleted successfully.
# 248 documents deleted successfully.
# 420 documents deleted successfully.
# 21 documents deleted successfully.
# 176 documents deleted successfully.
# 211 documents deleted successfully.
# 220 documents deleted successfully.
# 97 documents deleted successfully.
# 444 documents deleted successfully.
# 236 documents deleted successfully.
# 357 documents deleted successfully.
# 602 documents deleted successfully.
# 197 documents deleted successfully.
# 206 documents deleted successfully.
# 473 documents deleted successfully.
# 210 documents deleted successfully.
# 50 documents deleted successfully.
# 22 documents deleted successfully.
# 215 documents deleted successfully.
# 460 documents deleted successfully.
# 540 documents deleted successfully.
# 63 documents deleted successfully.
# 76 documents deleted successfully.
# 191 documents deleted successfully.
# 132 documents deleted successfully.
# 748 documents deleted successfully.
# 35 documents deleted successfully.
# 153 documents deleted successfully.
# 230 documents deleted successfully.
# 159 documents deleted successfully.
# 15 documents deleted successfully.
# 463 documents deleted successfully.
# 132 documents deleted successfully.
# 44 documents deleted successfully.
# 177 documents deleted successfully.
# 501 documents deleted successfully.
# 178 documents deleted successfully.
# 385 documents deleted successfully.
# 768 documents deleted successfully.
# 251 documents deleted successfully.
# 171 documents deleted successfully.
# 56 documents deleted successfully.
# 285 documents deleted successfully.
# 45 documents deleted successfully.
# 524 documents deleted successfully.
# 314 documents deleted successfully.
# 191 documents deleted successfully.
# 437 documents deleted successfully.
# 90 documents deleted successfully.
# 50 documents deleted successfully.
# 563 documents deleted successfully.
# 206 documents deleted successfully.
# 77 documents deleted successfully.
# 247 documents deleted successfully.
# 75 documents deleted successfully.
# 45 documents deleted successfully.
# 202 documents deleted successfully.
# 119 documents deleted successfully.
# 357 documents deleted successfully.
# 65 documents deleted successfully.
# 236 documents deleted successfully.
# 203 documents deleted successfully.
# 203 documents deleted successfully.
# 112 documents deleted successfully.
# 170 documents deleted successfully.
# 68 documents deleted successfully.
# 498 documents deleted successfully.
# 305 documents deleted successfully.
# 175 documents deleted successfully.
# 34 documents deleted successfully.
# 455 documents deleted successfully.
# 111 documents deleted successfully.
# 252 documents deleted successfully.
# 660 documents deleted successfully.
# 199 documents deleted successfully.
# 201 documents deleted successfully.
# 410 documents deleted successfully.
# 21 documents deleted successfully.
# 10 documents deleted successfully.
# 126 documents deleted successfully.
# 244 documents deleted successfully.
# 49 documents deleted successfully.
# 26 documents deleted successfully.
# 833 documents deleted successfully.
# 191 documents deleted successfully.
# 262 documents deleted successfully.
# 34 documents deleted successfully.
# 111 documents deleted successfully.
# 124 documents deleted successfully.
# 585 documents deleted successfully.
# 159 documents deleted successfully.
# 276 documents deleted successfully.
# 511 documents deleted successfully.
# 49 documents deleted successfully.
# 51 documents deleted successfully.
# 86 documents deleted successfully.
# 32 documents deleted successfully.
# 546 documents deleted successfully.
# 211 documents deleted successfully.
# 206 documents deleted successfully.
# 633 documents deleted successfully.
# 235 documents deleted successfully.
# 303 documents deleted successfully.
# 102 documents deleted successfully.
# 196 documents deleted successfully.
# 229 documents deleted successfully.
# 31 documents deleted successfully.
# 191 documents deleted successfully.
# 53 documents deleted successfully.
# 662 documents deleted successfully.
# 671 documents deleted successfully.
# 540 documents deleted successfully.
# 473 documents deleted successfully.
# 769 documents deleted successfully.
# 258 documents deleted successfully.
# 737 documents deleted successfully.
# 374 documents deleted successfully.
# 387 documents deleted successfully.
# 174 documents deleted successfully.
# 208 documents deleted successfully.
# 318 documents deleted successfully.
# 53 documents deleted successfully.
# 226 documents deleted successfully.
# 28 documents deleted successfully.
# 257 documents deleted successfully.
# 132 documents deleted successfully.
# 765 documents deleted successfully.
# 188 documents deleted successfully.
# 145 documents deleted successfully.
# 524 documents deleted successfully.
# 197 documents deleted successfully.
# 255 documents deleted successfully.
# 192 documents deleted successfully.
# 165 documents deleted successfully.
# 266 documents deleted successfully.
# 524 documents deleted successfully.
# 505 documents deleted successfully.
# 36 documents deleted successfully.
# 51 documents deleted successfully.
# 31 documents deleted successfully.
# 290 documents deleted successfully.
# 449 documents deleted successfully.
# 200 documents deleted successfully.
# 125 documents deleted successfully.
# 188 documents deleted successfully.
# 673 documents deleted successfully.
# 148 documents deleted successfully.
# 61 documents deleted successfully.
# 433 documents deleted successfully.
# 25 documents deleted successfully.
# 198 documents deleted successfully.
# 79 documents deleted successfully.
# 163 documents deleted successfully.
# 63 documents deleted successfully.
# 226 documents deleted successfully.
# 60 documents deleted successfully.
# 346 documents deleted successfully.
# 45 documents deleted successfully.
# 267 documents deleted successfully.
# 254 documents deleted successfully.
# 434 documents deleted successfully.
# 167 documents deleted successfully.
# 251 documents deleted successfully.
# 225 documents deleted successfully.
# 151 documents deleted successfully.
# 28 documents deleted successfully.
# 339 documents deleted successfully.
# 44 documents deleted successfully.
# 193 documents deleted successfully.
# 396 documents deleted successfully.
# 140 documents deleted successfully.
# 91 documents deleted successfully.
# 142 documents deleted successfully.
# 143 documents deleted successfully.
# 60 documents deleted successfully.
# 394 documents deleted successfully.
# 130 documents deleted successfully.
# 238 documents deleted successfully.
# 356 documents deleted successfully.
# 26 documents deleted successfully.
# 50 documents deleted successfully.
# 148 documents deleted successfully.
# 116 documents deleted successfully.
# 153 documents deleted successfully.
# 231 documents deleted successfully.
# 172 documents deleted successfully.
# 63 documents deleted successfully.
# 156 documents deleted successfully.
# 292 documents deleted successfully.
# 19 documents deleted successfully.
# 31 documents deleted successfully.
# 134 documents deleted successfully.
# 586 documents deleted successfully.
# 56 documents deleted successfully.
# 73 documents deleted successfully.
# 116 documents deleted successfully.
# 209 documents deleted successfully.
# 426 documents deleted successfully.
# 208 documents deleted successfully.
# 228 documents deleted successfully.
# 151 documents deleted successfully.
# 413 documents deleted successfully.
# 78 documents deleted successfully.
# 359 documents deleted successfully.
# 499 documents deleted successfully.
# 307 documents deleted successfully.
# 189 documents deleted successfully.
# 51 documents deleted successfully.
# 140 documents deleted successfully.
# 216 documents deleted successfully.
# 59 documents deleted successfully.
# 266 documents deleted successfully.
# 33 documents deleted successfully.
# 289 documents deleted successfully.
# 693 documents deleted successfully.
# 210 documents deleted successfully.
# 474 documents deleted successfully.
# 162 documents deleted successfully.
# 265 documents deleted successfully.
# 57 documents deleted successfully.
# 91 documents deleted successfully.
# 245 documents deleted successfully.
# 182 documents deleted successfully.
# 430 documents deleted successfully.
# 164 documents deleted successfully.
# 57 documents deleted successfully.
# 37 documents deleted successfully.
# 209 documents deleted successfully.
# 55 documents deleted successfully.
# 29 documents deleted successfully.
# 465 documents deleted successfully.
# 232 documents deleted successfully.
# 448 documents deleted successfully.
# 502 documents deleted successfully.
# 170 documents deleted successfully.
# 315 documents deleted successfully.
# 34 documents deleted successfully.
# 51 documents deleted successfully.
# 187 documents deleted successfully.
# 243 documents deleted successfully.
# 241 documents deleted successfully.
# 407 documents deleted successfully.
# 235 documents deleted successfully.
# 148 documents deleted successfully.
# 69 documents deleted successfully.
# 356 documents deleted successfully.
# 341 documents deleted successfully.
# 233 documents deleted successfully.
# 539 documents deleted successfully.
# 179 documents deleted successfully.
# 109 documents deleted successfully.
# 302 documents deleted successfully.
# 101 documents deleted successfully.
# 164 documents deleted successfully.
# 110 documents deleted successfully.
# 167 documents deleted successfully.
# 319 documents deleted successfully.
# 89 documents deleted successfully.
# 56 documents deleted successfully.
# 354 documents deleted successfully.
# 130 documents deleted successfully.
# 171 documents deleted successfully.
# 304 documents deleted successfully.
# 452 documents deleted successfully.
# 23 documents deleted successfully.
# 113 documents deleted successfully.
# 287 documents deleted successfully.
# 160 documents deleted successfully.
# 265 documents deleted successfully.
# 199 documents deleted successfully.
# 218 documents deleted successfully.
# 189 documents deleted successfully.
# 39 documents deleted successfully.
# 309 documents deleted successfully.
# 282 documents deleted successfully.
# 413 documents deleted successfully.
# 59 documents deleted successfully.
# 34 documents deleted successfully.
# 111 documents deleted successfully.
# 30 documents deleted successfully.
# 16 documents deleted successfully.
# 141 documents deleted successfully.
# 175 documents deleted successfully.
# 189 documents deleted successfully.
# 178 documents deleted successfully.
# 155 documents deleted successfully.
# 30 documents deleted successfully.
# 849 documents deleted successfully.
# 112 documents deleted successfully.
# 60 documents deleted successfully.
# 872 documents deleted successfully.
# 100 documents deleted successfully.
# 58 documents deleted successfully.
# 223 documents deleted successfully.
# 106 documents deleted successfully.
# 271 documents deleted successfully.
# 65 documents deleted successfully.
# 166 documents deleted successfully.
# 104 documents deleted successfully.
# 108 documents deleted successfully.
# 98 documents deleted successfully.
# 154 documents deleted successfully.
# 54 documents deleted successfully.
# 132 documents deleted successfully.
# 128 documents deleted successfully.
# 263 documents deleted successfully.
# 143 documents deleted successfully.
# 80 documents deleted successfully.
# 50 documents deleted successfully.
# 28 documents deleted successfully.
# 60 documents deleted successfully.
# 629 documents deleted successfully.
# 847 documents deleted successfully.
# 131 documents deleted successfully.
# 286 documents deleted successfully.
# 379 documents deleted successfully.
# 49 documents deleted successfully.
# 54 documents deleted successfully.
# 185 documents deleted successfully.
# 149 documents deleted successfully.
# 147 documents deleted successfully.
# 102 documents deleted successfully.
# 15 documents deleted successfully.
# 41 documents deleted successfully.
# 487 documents deleted successfully.
# 798 documents deleted successfully.
# 195 documents deleted successfully.
# 259 documents deleted successfully.
# 19 documents deleted successfully.
# 186 documents deleted successfully.
# 189 documents deleted successfully.
# 99 documents deleted successfully.
# 101 documents deleted successfully.
# 186 documents deleted successfully.
# 24 documents deleted successfully.
# 119 documents deleted successfully.
# 110 documents deleted successfully.
# 94 documents deleted successfully.
# 247 documents deleted successfully.
# 310 documents deleted successfully.
# 67 documents deleted successfully.
# 83 documents deleted successfully.
# 178 documents deleted successfully.
# 140 documents deleted successfully.
# 535 documents deleted successfully.
# 249 documents deleted successfully.
# 133 documents deleted successfully.
# 370 documents deleted successfully.
# 96 documents deleted successfully.
# 287 documents deleted successfully.
# 66 documents deleted successfully.
# 136 documents deleted successfully.
# 68 documents deleted successfully.
# 321 documents deleted successfully.
# 439 documents deleted successfully.
# 294 documents deleted successfully.
# 546 documents deleted successfully.
# 20 documents deleted successfully.
# 268 documents deleted successfully.
# 70 documents deleted successfully.
# 189 documents deleted successfully.
# 132 documents deleted successfully.
# 82 documents deleted successfully.
# 198 documents deleted successfully.
# 538 documents deleted successfully.
# 47 documents deleted successfully.
# 33 documents deleted successfully.
# 123 documents deleted successfully.
# 244 documents deleted successfully.
# 72 documents deleted successfully.
# 37 documents deleted successfully.
# 134 documents deleted successfully.
# 373 documents deleted successfully.
# 425 documents deleted successfully.
# 235 documents deleted successfully.
# 180 documents deleted successfully.
# 230 documents deleted successfully.
# 445 documents deleted successfully.
# 507 documents deleted successfully.
# 140 documents deleted successfully.
# 254 documents deleted successfully.
# 580 documents deleted successfully.
# 115 documents deleted successfully.
# 285 documents deleted successfully.
# 113 documents deleted successfully.
# 52 documents deleted successfully.
# 166 documents deleted successfully.
# 655 documents deleted successfully.
# 213 documents deleted successfully.
# 71 documents deleted successfully.
# 26 documents deleted successfully.
# 373 documents deleted successfully.
# 289 documents deleted successfully.
# 246 documents deleted successfully.
# 177 documents deleted successfully.
# 302 documents deleted successfully.
# 191 documents deleted successfully.
# 15 documents deleted successfully.
# 228 documents deleted successfully.
# 447 documents deleted successfully.
# 236 documents deleted successfully.
# 32 documents deleted successfully.
# 237 documents deleted successfully.
# 54 documents deleted successfully.
# 189 documents deleted successfully.
# 559 documents deleted successfully.
# 61 documents deleted successfully.
# 192 documents deleted successfully.
# 51 documents deleted successfully.
# 103 documents deleted successfully.
# 12 documents deleted successfully.
# 37 documents deleted successfully.
# 60 documents deleted successfully.
# 172 documents deleted successfully.
# 263 documents deleted successfully.
# 45 documents deleted successfully.
# 237 documents deleted successfully.
# 38 documents deleted successfully.
# 139 documents deleted successfully.
# 598 documents deleted successfully.
# 160 documents deleted successfully.
# 725 documents deleted successfully.
# 163 documents deleted successfully.
# 170 documents deleted successfully.
# 156 documents deleted successfully.
# 62 documents deleted successfully.
# 46 documents deleted successfully.
# 119 documents deleted successfully.
# 548 documents deleted successfully.
# 221 documents deleted successfully.
# 40 documents deleted successfully.
# 78 documents deleted successfully.
# 272 documents deleted successfully.
# 69 documents deleted successfully.
# 63 documents deleted successfully.
# 103 documents deleted successfully.
# 209 documents deleted successfully.
# 189 documents deleted successfully.
# 163 documents deleted successfully.
# 665 documents deleted successfully.
# 230 documents deleted successfully.
# 46 documents deleted successfully.
# 421 documents deleted successfully.
# 374 documents deleted successfully.
# 216 documents deleted successfully.
# 605 documents deleted successfully.
# 153 documents deleted successfully.
# 121 documents deleted successfully.
# 454 documents deleted successfully.
# 58 documents deleted successfully.
# 133 documents deleted successfully.
# 78 documents deleted successfully.
# 292 documents deleted successfully.
# 108 documents deleted successfully.
# 193 documents deleted successfully.
# 241 documents deleted successfully.
# 188 documents deleted successfully.
# 557 documents deleted successfully.
# 298 documents deleted successfully.
# 54 documents deleted successfully.
# 178 documents deleted successfully.
# 171 documents deleted successfully.
# 69 documents deleted successfully.
# 215 documents deleted successfully.
# 198 documents deleted successfully.
# 493 documents deleted successfully.
# 237 documents deleted successfully.
# 80 documents deleted successfully.
# 639 documents deleted successfully.
# 425 documents deleted successfully.
# 79 documents deleted successfully.
# 522 documents deleted successfully.
# 222 documents deleted successfully.
# 134 documents deleted successfully.
# 241 documents deleted successfully.
# 174 documents deleted successfully.
# 65 documents deleted successfully.
# 267 documents deleted successfully.
# 533 documents deleted successfully.
# 262 documents deleted successfully.
# 50 documents deleted successfully.
# 41 documents deleted successfully.
# 184 documents deleted successfully.
# 58 documents deleted successfully.
# 263 documents deleted successfully.
# 192 documents deleted successfully.
# 192 documents deleted successfully.
# 91 documents deleted successfully.
# 162 documents deleted successfully.
# 275 documents deleted successfully.
# 485 documents deleted successfully.
# 161 documents deleted successfully.
# 58 documents deleted successfully.
# 233 documents deleted successfully.
# 107 documents deleted successfully.
# 616 documents deleted successfully.
# 49 documents deleted successfully.
# 196 documents deleted successfully.
# 111 documents deleted successfully.
# 159 documents deleted successfully.
# 155 documents deleted successfully.
# 254 documents deleted successfully.
# 111 documents deleted successfully.
# 246 documents deleted successfully.
# 238 documents deleted successfully.
# 50 documents deleted successfully.
# 698 documents deleted successfully.
# 226 documents deleted successfully.
# 206 documents deleted successfully.
# 263 documents deleted successfully.
# 51 documents deleted successfully.
# 27 documents deleted successfully.
# 39 documents deleted successfully.
# 252 documents deleted successfully.
# 47 documents deleted successfully.
# 34 documents deleted successfully.
# 285 documents deleted successfully.
# 224 documents deleted successfully.
# 79 documents deleted successfully.
# 119 documents deleted successfully.
# 302 documents deleted successfully.
# 122 documents deleted successfully.
# 70 documents deleted successfully.
# 63 documents deleted successfully.
# 158 documents deleted successfully.
# 136 documents deleted successfully.
# 148 documents deleted successfully.
# 241 documents deleted successfully.
# 253 documents deleted successfully.
# 26 documents deleted successfully.
# 645 documents deleted successfully.
# 228 documents deleted successfully.
# 18 documents deleted successfully.
# 16 documents deleted successfully.
# 129 documents deleted successfully.
# 44 documents deleted successfully.
# 155 documents deleted successfully.
# 249 documents deleted successfully.
# 116 documents deleted successfully.
# 197 documents deleted successfully.
# 209 documents deleted successfully.
# 327 documents deleted successfully.
# 55 documents deleted successfully.
# 159 documents deleted successfully.
# 892 documents deleted successfully.
# 287 documents deleted successfully.
# 311 documents deleted successfully.
# 106 documents deleted successfully.
# 53 documents deleted successfully.
# 17 documents deleted successfully.
# 413 documents deleted successfully.
# 237 documents deleted successfully.
# 58 documents deleted successfully.
# 44 documents deleted successfully.
# 270 documents deleted successfully.
# 169 documents deleted successfully.
# 136 documents deleted successfully.
# 473 documents deleted successfully.
# 26 documents deleted successfully.
# 82 documents deleted successfully.
# 154 documents deleted successfully.
# 306 documents deleted successfully.
# 173 documents deleted successfully.
# 522 documents deleted successfully.
# 59 documents deleted successfully.
# 25 documents deleted successfully.
# 39 documents deleted successfully.
# 165 documents deleted successfully.
# 71 documents deleted successfully.
# 105 documents deleted successfully.
# 10 documents deleted successfully.
# 215 documents deleted successfully.
# 343 documents deleted successfully.
# 101 documents deleted successfully.
# 196 documents deleted successfully.
# 88 documents deleted successfully.
# 23 documents deleted successfully.
# 361 documents deleted successfully.
# 575 documents deleted successfully.
# 86 documents deleted successfully.
# 224 documents deleted successfully.
# 72 documents deleted successfully.
# 75 documents deleted successfully.
# 19 documents deleted successfully.
# 67 documents deleted successfully.
# 645 documents deleted successfully.
# 79 documents deleted successfully.
# 356 documents deleted successfully.
# 79 documents deleted successfully.
# 436 documents deleted successfully.
# 377 documents deleted successfully.
# 218 documents deleted successfully.
# 210 documents deleted successfully.
# 67 documents deleted successfully.
# 144 documents deleted successfully.
# 33 documents deleted successfully.
# 123 documents deleted successfully.
# 350 documents deleted successfully.
# 16 documents deleted successfully.
# 235 documents deleted successfully.
# 163 documents deleted successfully.
# 42 documents deleted successfully.
# 206 documents deleted successfully.
# 50 documents deleted successfully.
# 182 documents deleted successfully.
# 55 documents deleted successfully.
# 244 documents deleted successfully.
# 472 documents deleted successfully.
# 39 documents deleted successfully.
# 322 documents deleted successfully.
# 219 documents deleted successfully.
# 293 documents deleted successfully.
# 197 documents deleted successfully.
# 387 documents deleted successfully.
# 39 documents deleted successfully.
# 131 documents deleted successfully.
# 67 documents deleted successfully.
# 52 documents deleted successfully.
# 120 documents deleted successfully.
# 84 documents deleted successfully.
# 245 documents deleted successfully.
# 70 documents deleted successfully.
# 41 documents deleted successfully.
# 11 documents deleted successfully.
# 63 documents deleted successfully.
# 45 documents deleted successfully.
# 223 documents deleted successfully.
# 26 documents deleted successfully.
# 158 documents deleted successfully.
# 239 documents deleted successfully.
# 80 documents deleted successfully.
# 232 documents deleted successfully.
# 241 documents deleted successfully.
# 176 documents deleted successfully.
# 223 documents deleted successfully.
# 240 documents deleted successfully.
# 487 documents deleted successfully.
# 621 documents deleted successfully.
# 87 documents deleted successfully.
# 104 documents deleted successfully.
# 94 documents deleted successfully.
# 199 documents deleted successfully.
# 176 documents deleted successfully.
# 232 documents deleted successfully.
# 590 documents deleted successfully.
# 232 documents deleted successfully.
# 155 documents deleted successfully.
# 260 documents deleted successfully.
# 182 documents deleted successfully.
# 229 documents deleted successfully.
# 221 documents deleted successfully.
# 223 documents deleted successfully.
# 171 documents deleted successfully.
# 40 documents deleted successfully.
# 109 documents deleted successfully.
# 168 documents deleted successfully.
# 544 documents deleted successfully.
# 63 documents deleted successfully.
# 57 documents deleted successfully.
# 125 documents deleted successfully.
# 288 documents deleted successfully.
# 273 documents deleted successfully.
# 21 documents deleted successfully.
# 88 documents deleted successfully.
# 201 documents deleted successfully.
# 206 documents deleted successfully.
# 58 documents deleted successfully.
# 102 documents deleted successfully.
# 116 documents deleted successfully.
# 45 documents deleted successfully.
# 225 documents deleted successfully.
# 60 documents deleted successfully.
# 188 documents deleted successfully.
# 424 documents deleted successfully.
# 59 documents deleted successfully.
# 35 documents deleted successfully.
# 120 documents deleted successfully.
# 202 documents deleted successfully.
# 252 documents deleted successfully.
# 389 documents deleted successfully.
# 18 documents deleted successfully.
# 244 documents deleted successfully.
# 12 documents deleted successfully.
# 138 documents deleted successfully.
# 43 documents deleted successfully.
# 93 documents deleted successfully.
# 326 documents deleted successfully.
# 162 documents deleted successfully.
# 295 documents deleted successfully.
# 41 documents deleted successfully.
# 189 documents deleted successfully.
# 151 documents deleted successfully.
# 227 documents deleted successfully.
# 1082 documents deleted successfully.
# 197 documents deleted successfully.
# 674 documents deleted successfully.
# 115 documents deleted successfully.
# 523 documents deleted successfully.
# 52 documents deleted successfully.
# 47 documents deleted successfully.
# 377 documents deleted successfully.
# 197 documents deleted successfully.
# 117 documents deleted successfully.
# 114 documents deleted successfully.
# 121 documents deleted successfully.
# 287 documents deleted successfully.
# 166 documents deleted successfully.
# 113 documents deleted successfully.
# 398 documents deleted successfully.
# 243 documents deleted successfully.
# 235 documents deleted successfully.
# 44 documents deleted successfully.
# 57 documents deleted successfully.
# 157 documents deleted successfully.
# 55 documents deleted successfully.
# 43 documents deleted successfully.
# 592 documents deleted successfully.
# 233 documents deleted successfully.
# 39 documents deleted successfully.
# 260 documents deleted successfully.
# 37 documents deleted successfully.
# 50 documents deleted successfully.
# 67 documents deleted successfully.
# 36 documents deleted successfully.
# 569 documents deleted successfully.
# 338 documents deleted successfully.
# 26 documents deleted successfully.
# 244 documents deleted successfully.
# 148 documents deleted successfully.
# 64 documents deleted successfully.
# 65 documents deleted successfully.
# 203 documents deleted successfully.
# 124 documents deleted successfully.
# 149 documents deleted successfully.
# 134 documents deleted successfully.
# 96 documents deleted successfully.
# 172 documents deleted successfully.
# 236 documents deleted successfully.
# 176 documents deleted successfully.
# 56 documents deleted successfully.
# 50 documents deleted successfully.
# 60 documents deleted successfully.
# 58 documents deleted successfully.
# 28 documents deleted successfully.
# 48 documents deleted successfully.
# 78 documents deleted successfully.
# 103 documents deleted successfully.
# 128 documents deleted successfully.
# 85 documents deleted successfully.
# 162 documents deleted successfully.
# 77 documents deleted successfully.
# 227 documents deleted successfully.
# 48 documents deleted successfully.
# 90 documents deleted successfully.
# 79 documents deleted successfully.
# 41 documents deleted successfully.
# 172 documents deleted successfully.
# 176 documents deleted successfully.
# 162 documents deleted successfully.
# 141 documents deleted successfully.
# 55 documents deleted successfully.
# 104 documents deleted successfully.
# 60 documents deleted successfully.
# 369 documents deleted successfully.
# 45 documents deleted successfully.
# 173 documents deleted successfully.
# 191 documents deleted successfully.
# 674 documents deleted successfully.
# 470 documents deleted successfully.
# 28 documents deleted successfully.
# 437 documents deleted successfully.
# 45 documents deleted successfully.
# 206 documents deleted successfully.
# 57 documents deleted successfully.
# 100 documents deleted successfully.
# 190 documents deleted successfully.
# 22 documents deleted successfully.
# 101 documents deleted successfully.
# 298 documents deleted successfully.
# 333 documents deleted successfully.
# 12 documents deleted successfully.
# 535 documents deleted successfully.
# 44 documents deleted successfully.
# 576 documents deleted successfully.
# 176 documents deleted successfully.
# 52 documents deleted successfully.
# 76 documents deleted successfully.
# 254 documents deleted successfully.
# 60 documents deleted successfully.
# 199 documents deleted successfully.
# 189 documents deleted successfully.
# 213 documents deleted successfully.
# 140 documents deleted successfully.
# 91 documents deleted successfully.
# 177 documents deleted successfully.
# 913 documents deleted successfully.
# 329 documents deleted successfully.
# ...
# 76 documents deleted successfully.
# 84 documents deleted successfully.
# 218 documents deleted successfully.
# 198 documents deleted successfully.
# 56 documents deleted successfully.
# 56 documents deleted successfully.
# 88 documents deleted successfully.
# 68 documents deleted successfully.
# 114 documents deleted successfully.
# 127 documents deleted successfully.
# 15 documents deleted successfully.
# 106 documents deleted successfully.
# 200 documents deleted successfully.
# 38 documents deleted successfully.
# 151 documents deleted successfully.
# 47 documents deleted successfully.
# 57 documents deleted successfully.
# 131 documents deleted successfully.
# 54 documents deleted successfully.
# 197 documents deleted successfully.
# 40 documents deleted successfully.
# 149 documents deleted successfully.
# 345 documents deleted successfully.
# 179 documents deleted successfully.
# 15 documents deleted successfully.
# 127 documents deleted successfully.
# 49 documents deleted successfully.
# 161 documents deleted successfully.
# 322 documents deleted successfully.
# 50 documents deleted successfully.
# 162 documents deleted successfully.
# 169 documents deleted successfully.
# 175 documents deleted successfully.
# 102 documents deleted successfully.
# 63 documents deleted successfully.
# 60 documents deleted successfully.
# 58 documents deleted successfully.
# 77 documents deleted successfully.
# 353 documents deleted successfully.
# 89 documents deleted successfully.
# 186 documents deleted successfully.
# 146 documents deleted successfully.
# 184 documents deleted successfully.
# 22 documents deleted successfully.
# 31 documents deleted successfully.
# 122 documents deleted successfully.
# 155 documents deleted successfully.
# 77 documents deleted successfully.
# 80 documents deleted successfully.
# 170 documents deleted successfully.
# 46 documents deleted successfully.
# 22 documents deleted successfully.
# 59 documents deleted successfully.
# 68 documents deleted successfully.
# 28 documents deleted successfully.
# 159 documents deleted successfully.
# 113 documents deleted successfully.
# 60 documents deleted successfully.
# 17 documents deleted successfully.
# 69 documents deleted successfully.
# 44 documents deleted successfully.
# 194 documents deleted successfully.
# 157 documents deleted successfully.
# 245 documents deleted successfully.
# 195 documents deleted successfully.
# 218 documents deleted successfully.
# 47 documents deleted successfully.
# 159 documents deleted successfully.
# 233 documents deleted successfully.
# 57 documents deleted successfully.
# 116 documents deleted successfully.
# 58 documents deleted successfully.
# 28 documents deleted successfully.
# 171 documents deleted successfully.
# 172 documents deleted successfully.
# 56 documents deleted successfully.
# 82 documents deleted successfully.
# 43 documents deleted successfully.
# 155 documents deleted successfully.
# 113 documents deleted successfully.
# 88 documents deleted successfully.
# 71 documents deleted successfully.
# 33 documents deleted successfully.
# 246 documents deleted successfully.
# 159 documents deleted successfully.
# 78 documents deleted successfully.
# 41 documents deleted successfully.
# 61 documents deleted successfully.
# 12 documents deleted successfully.
# 112 documents deleted successfully.
# 46 documents deleted successfully.
# 166 documents deleted successfully.
# 244 documents deleted successfully.
# 91 documents deleted successfully.
# 219 documents deleted successfully.
# 20 documents deleted successfully.
# 51 documents deleted successfully.
# 27 documents deleted successfully.
# 176 documents deleted successfully.
# 99 documents deleted successfully.
# 173 documents deleted successfully.
# 71 documents deleted successfully.
# 215 documents deleted successfully.
# 212 documents deleted successfully.
# 39 documents deleted successfully.
# 55 documents deleted successfully.
# 47 documents deleted successfully.
# 19 documents deleted successfully.
# 36 documents deleted successfully.
# 207 documents deleted successfully.
# 307 documents deleted successfully.
# 220 documents deleted successfully.
# 19 documents deleted successfully.
# 172 documents deleted successfully.
# 50 documents deleted successfully.
# 53 documents deleted successfully.
# 24 documents deleted successfully.
# 191 documents deleted successfully.
# 181 documents deleted successfully.
# 158 documents deleted successfully.
# 92 documents deleted successfully.
# 64 documents deleted successfully.
# 16 documents deleted successfully.
# 57 documents deleted successfully.
# 94 documents deleted successfully.
# 236 documents deleted successfully.
# 141 documents deleted successfully.
# 160 documents deleted successfully.
# 16 documents deleted successfully.
# 39 documents deleted successfully.
# 54 documents deleted successfully.
# 50 documents deleted successfully.
# 143 documents deleted successfully.
# 180 documents deleted successfully.
# 137 documents deleted successfully.
# 16 documents deleted successfully.
# 90 documents deleted successfully.
# 97 documents deleted successfully.
# 13 documents deleted successfully.
# 178 documents deleted successfully.
# 47 documents deleted successfully.
# 172 documents deleted successfully.
# 30 documents deleted successfully.
# 37 documents deleted successfully.
# 18 documents deleted successfully.
# 39 documents deleted successfully.
# 58 documents deleted successfully.
# 143 documents deleted successfully.
# 49 documents deleted successfully.
# 30 documents deleted successfully.
# 43 documents deleted successfully.
# 244 documents deleted successfully.
# 5 documents deleted successfully.
# 171 documents deleted successfully.
# 161 documents deleted successfully.
# 265 documents deleted successfully.
# 7 documents deleted successfully.
# 42 documents deleted successfully.
# 96 documents deleted successfully.
# 120 documents deleted successfully.
# 18 documents deleted successfully.
# 75 documents deleted successfully.
# 35 documents deleted successfully.
# 188 documents deleted successfully.
# 104 documents deleted successfully.
# 77 documents deleted successfully.
# 12 documents deleted successfully.
# 174 documents deleted successfully.
# 33 documents deleted successfully.
# 106 documents deleted successfully.
# 105 documents deleted successfully.
# 156 documents deleted successfully.
# 259 documents deleted successfully.
# 38 documents deleted successfully.
# 54 documents deleted successfully.
# 69 documents deleted successfully.
# 33 documents deleted successfully.
# 52 documents deleted successfully.
# 235 documents deleted successfully.
# 81 documents deleted successfully.
# 41 documents deleted successfully.
# 82 documents deleted successfully.
# 60 documents deleted successfully.
# 213 documents deleted successfully.
# 94 documents deleted successfully.
# 51 documents deleted successfully.
# 55 documents deleted successfully.
# 28 documents deleted successfully.
# 91 documents deleted successfully.
# 78 documents deleted successfully.
# 147 documents deleted successfully.
# 67 documents deleted successfully.
# 179 documents deleted successfully.
# 194 documents deleted successfully.
# 77 documents deleted successfully.
# 254 documents deleted successfully.
# 143 documents deleted successfully.
# 62 documents deleted successfully.
# 52 documents deleted successfully.
# 216 documents deleted successfully.
# 222 documents deleted successfully.
# 57 documents deleted successfully.
# 63 documents deleted successfully.
# 157 documents deleted successfully.
# 48 documents deleted successfully.
# 57 documents deleted successfully.
# 178 documents deleted successfully.
# 88 documents deleted successfully.
# 28 documents deleted successfully.
# 177 documents deleted successfully.
# 99 documents deleted successfully.
# 259 documents deleted successfully.
# 38 documents deleted successfully.
# 22 documents deleted successfully.
# 91 documents deleted successfully.
# 55 documents deleted successfully.
# 49 documents deleted successfully.
# 31 documents deleted successfully.
# 60 documents deleted successfully.
# 150 documents deleted successfully.
# 13 documents deleted successfully.
# 68 documents deleted successfully.
# 215 documents deleted successfully.
# 15 documents deleted successfully.
# 32 documents deleted successfully.
# 70 documents deleted successfully.
# 42 documents deleted successfully.
# 35 documents deleted successfully.
# 80 documents deleted successfully.
# 153 documents deleted successfully.
# 263 documents deleted successfully.
# 34 documents deleted successfully.
# 21 documents deleted successfully.
# 173 documents deleted successfully.
# 90 documents deleted successfully.
# 95 documents deleted successfully.
# 68 documents deleted successfully.
# 43 documents deleted successfully.
# 33 documents deleted successfully.
# 52 documents deleted successfully.
# 46 documents deleted successfully.
# 85 documents deleted successfully.
# 74 documents deleted successfully.
# 59 documents deleted successfully.
# 178 documents deleted successfully.
# 59 documents deleted successfully.
# 41 documents deleted successfully.
# 67 documents deleted successfully.
# 296 documents deleted successfully.
# 107 documents deleted successfully.
# 84 documents deleted successfully.
# 170 documents deleted successfully.
# 287 documents deleted successfully.
# 64 documents deleted successfully.
# 67 documents deleted successfully.
# 50 documents deleted successfully.
# 113 documents deleted successfully.
# 161 documents deleted successfully.
# 79 documents deleted successfully.
# 180 documents deleted successfully.
# 58 documents deleted successfully.
# 151 documents deleted successfully.
# 161 documents deleted successfully.
# 17 documents deleted successfully.
# 52 documents deleted successfully.
# 176 documents deleted successfully.
# 14 documents deleted successfully.
# 234 documents deleted successfully.
# 12 documents deleted successfully.
# 65 documents deleted successfully.
# 141 documents deleted successfully.
# 120 documents deleted successfully.
# 142 documents deleted successfully.
# 61 documents deleted successfully.
# 107 documents deleted successfully.
# 84 documents deleted successfully.
# 22 documents deleted successfully.
# 154 documents deleted successfully.
# 78 documents deleted successfully.
# 177 documents deleted successfully.
# 54 documents deleted successfully.
# 49 documents deleted successfully.
# 196 documents deleted successfully.
# 189 documents deleted successfully.
# 16 documents deleted successfully.
# 273 documents deleted successfully.
# 94 documents deleted successfully.
# 59 documents deleted successfully.
# 196 documents deleted successfully.
# 117 documents deleted successfully.
# 76 documents deleted successfully.
# 58 documents deleted successfully.
# 83 documents deleted successfully.
# 347 documents deleted successfully.
# 52 documents deleted successfully.
# 334 documents deleted successfully.
# 23 documents deleted successfully.
# 71 documents deleted successfully.
# 45 documents deleted successfully.
# 20 documents deleted successfully.
# 157 documents deleted successfully.
# 79 documents deleted successfully.
# 20 documents deleted successfully.
# 107 documents deleted successfully.
# 65 documents deleted successfully.
# 17 documents deleted successfully.
# 90 documents deleted successfully.
# 10 documents deleted successfully.
# 27 documents deleted successfully.
# 10 documents deleted successfully.
# 43 documents deleted successfully.
# 187 documents deleted successfully.
# 67 documents deleted successfully.
# 19 documents deleted successfully.
# 134 documents deleted successfully.
# 164 documents deleted successfully.
# 178 documents deleted successfully.
# 91 documents deleted successfully.
# 265 documents deleted successfully.
# 127 documents deleted successfully.
# 44 documents deleted successfully.
# 205 documents deleted successfully.
# 49 documents deleted successfully.
# 25 documents deleted successfully.
# 372 documents deleted successfully.
# 52 documents deleted successfully.
# 58 documents deleted successfully.
# 56 documents deleted successfully.
# 207 documents deleted successfully.
# 40 documents deleted successfully.
# 143 documents deleted successfully.
# 133 documents deleted successfully.
# 61 documents deleted successfully.
# 226 documents deleted successfully.
# 177 documents deleted successfully.
# 163 documents deleted successfully.
# 50 documents deleted successfully.
# 16 documents deleted successfully.
# 19 documents deleted successfully.
# 63 documents deleted successfully.
# 94 documents deleted successfully.
# 64 documents deleted successfully.
# 12 documents deleted successfully.
# 20 documents deleted successfully.
# 227 documents deleted successfully.
# 42 documents deleted successfully.
# 91 documents deleted successfully.
# 97 documents deleted successfully.
# 101 documents deleted successfully.
# 68 documents deleted successfully.
# 61 documents deleted successfully.
# 30 documents deleted successfully.
# 60 documents deleted successfully.
# 156 documents deleted successfully.
# 185 documents deleted successfully.
# 32 documents deleted successfully.
# 124 documents deleted successfully.
# 226 documents deleted successfully.
# 126 documents deleted successfully.
# 196 documents deleted successfully.
# 134 documents deleted successfully.
# 223 documents deleted successfully.
# 79 documents deleted successfully.
# 45 documents deleted successfully.
# 19 documents deleted successfully.
# 14 documents deleted successfully.
# 38 documents deleted successfully.
# 56 documents deleted successfully.
# 173 documents deleted successfully.
# 44 documents deleted successfully.
# 127 documents deleted successfully.
# 120 documents deleted successfully.
# 67 documents deleted successfully.
# 160 documents deleted successfully.
# 11 documents deleted successfully.
# 199 documents deleted successfully.
# 56 documents deleted successfully.
# 129 documents deleted successfully.
# 63 documents deleted successfully.
# 18 documents deleted successfully.
# 58 documents deleted successfully.
# 67 documents deleted successfully.
# 59 documents deleted successfully.
# 94 documents deleted successfully.
# 205 documents deleted successfully.
# 324 documents deleted successfully.
# 199 documents deleted successfully.
# 234 documents deleted successfully.
# 56 documents deleted successfully.
# 253 documents deleted successfully.
# 7 documents deleted successfully.
# 48 documents deleted successfully.
# 60 documents deleted successfully.
# 97 documents deleted successfully.
# 263 documents deleted successfully.
# 132 documents deleted successfully.
# 57 documents deleted successfully.
# 60 documents deleted successfully.
# 58 documents deleted successfully.
# 60 documents deleted successfully.
# 10 documents deleted successfully.
# 131 documents deleted successfully.
# 79 documents deleted successfully.
# 221 documents deleted successfully.
# 30 documents deleted successfully.
# 47 documents deleted successfully.
# 76 documents deleted successfully.
# 123 documents deleted successfully.
# 50 documents deleted successfully.
# 51 documents deleted successfully.
# 136 documents deleted successfully.
# 71 documents deleted successfully.
# 184 documents deleted successfully.
# 118 documents deleted successfully.
# 196 documents deleted successfully.
# 91 documents deleted successfully.
# 28 documents deleted successfully.
# 237 documents deleted successfully.
# 190 documents deleted successfully.
# 210 documents deleted successfully.
# 64 documents deleted successfully.
# 47 documents deleted successfully.
# 49 documents deleted successfully.
# 5 documents deleted successfully.
# 304 documents deleted successfully.
# 156 documents deleted successfully.
# 138 documents deleted successfully.
# 93 documents deleted successfully.
# 57 documents deleted successfully.
# 27 documents deleted successfully.
# 45 documents deleted successfully.
# 225 documents deleted successfully.
# 36 documents deleted successfully.
# 115 documents deleted successfully.
# 11 documents deleted successfully.
# 48 documents deleted successfully.
# 51 documents deleted successfully.
# 38 documents deleted successfully.
# 48 documents deleted successfully.
# 40 documents deleted successfully.
# 97 documents deleted successfully.
# 64 documents deleted successfully.
# 55 documents deleted successfully.
# 37 documents deleted successfully.
# 63 documents deleted successfully.
# 103 documents deleted successfully.
# 164 documents deleted successfully.
# 66 documents deleted successfully.
# 25 documents deleted successfully.
# 66 documents deleted successfully.
# 192 documents deleted successfully.
# 190 documents deleted successfully.
